# %% [markdown]
# # Mod 1 Project

# %% [markdown]
# ## Importing Data:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols
# %matplotlib inline
import folium

# %%
df = pd.read_csv("kc_house_data.csv")

# %% [markdown]
# ## Aims and Articles:

# %% [markdown]
# We are attempting to create a model for house price in the Seattle housing market
#
# https://en.wikipedia.org/wiki/King_County,_Washington
# https://www.seattletimes.com/business/real-estate/why-are-seattle-area-home-prices-so-high/
#
# Aims to keep in mind:
# We need pick at least 3 coefficients for your final model of house price.
#
# Explain their impact on the price of a house in this dataset.
#
# Model should not include any predictors with p-values greater than .05.
#
# # EDA

# %% [markdown]
# ## Basics

# %%
df.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
# 5    101930     1.0         0.0   0.0  ...     11        3890         1530.0
# 6      6819     2.0         0.0   0.0  ...      7        1715              ?
# 7      9711     1.0         0.0   NaN  ...      7        1060            0.0
# 8      7470     1.0         0.0   0.0  ...      7        1050          730.0
# 9      6560     2.0         0.0   0.0  ...      7        1890            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
# 5     2001           0.0    98053  47.6561 -122.005           4760      101930
# 6     1995           0.0    98003  47.3097 -122.327           2238        6819
# 7     1963           0.0    98198  47.4095 -122.315           1650        9711
# 8     1960           0.0    98146  47.5123 -122.337           1780        8113
# 9     2003           0.0    98038  47.3684 -122.031           2390        7570
#
# [10 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# std    4.141264e+04      0.539683      0.086825      0.765686      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above      yr_built  yr_renovated       zipcode  \
# count  21597.000000  21597.000000  21597.000000  17755.000000  21597.000000
# mean       7.657915   1788.596842   1970.999676     83.636778  98077.951845
# std        1.173200    827.759761     29.375234    399.946414     53.513072
# min        3.000000    370.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000   1190.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000   1560.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000   2210.000000   1997.000000      0.000000  98118.000000
# max       13.000000   9410.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000   21597.000000   21597.000000
# mean      47.560093   -122.213982    1986.620318   12758.283512
# std        0.138552      0.140724     685.230472   27274.441950
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471100   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.231000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# The above table gives us a general overview to spot any problems with the data
#
# There is no data that is negative when it should be positive
#
# A house with 33 bedrooms! Worth checking out in case its an anomoly
#
# describe() not showing date column (expected, as this may be a datetime object)
#
# describe() not showing sqft_basement column, which is interesting and needs a look at

# %%
df.shape
# Out:
# (21597, 21)

# %% [markdown]
# Column Names and descriptions for Kings County Data Set
#
# * **id** - unique identified for a house
# * **dateDate** - The year the house was most recently sold
# * **pricePrice** -  is prediction target (so is this not sales price?)
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  square footage of the home
# * **sqft_lotsquare** -  square footage of the lot (ie the size of the land the house is on)
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed (given as a number of views, most viewed house has 4)
# * **condition** - How good the condition is ( Overall ) (ranked from 1 to 5)
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate (worth noting these are negative latitudes)
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# Above tables show that sqft_basement is an object and we have null values in the waterfront, view, and yr_renovated columns.

# %%
duplicates = df.duplicated(subset=["id"], keep="first")
display(duplicates.value_counts())

duplicates = df.duplicated(subset=["id", "date"], keep="first")
display(duplicates.value_counts())
# Out:
# False    21420
# True       177
# dtype: int64
# False    21597
# dtype: int64

# %% [markdown]
# This suggests that we dont have duplicate entries
#
# 177 properties were bought and resold in this timeframe

# %%
for x in list(df.columns):
    print(df[x].value_counts().head(10))
# Out:
# 795000620     3
# 1825069031    2
# 2019200220    2
# 7129304540    2
# 1781500435    2
# 3969300030    2
# 2560801222    2
# 3883800011    2
# 2228900270    2
# 251300110     2
# Name: id, dtype: int64
# 6/23/2014    142
# 6/26/2014    131
# 6/25/2014    131
# 7/8/2014     127
# 4/27/2015    126
# 3/25/2015    123
# 4/14/2015    121
# 4/22/2015    121
# 4/28/2015    121
# 7/9/2014     121
# Name: date, dtype: int64
# 350000.0    172
# 450000.0    172
# 550000.0    159
# 500000.0    152
# 425000.0    150
# 325000.0    148
# 400000.0    145
# 375000.0    138
# 300000.0    133
# 525000.0    131
# Name: price, dtype: int64
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# Name: bedrooms, dtype: int64
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# Name: bathrooms, dtype: int64
# 1300    138
# 1400    135
# 1440    133
# 1660    129
# 1010    129
# 1800    129
# 1820    128
# 1480    125
# 1720    125
# 1540    124
# Name: sqft_living, dtype: int64
# 5000    358
# 6000    290
# 4000    251
# 7200    220
# 7500    119
# 4800    119
# 4500    114
# 8400    111
# 9600    109
# 3600    103
# Name: sqft_lot, dtype: int64
# 1.0    10673
# 2.0     8235
# 1.5     1910
# 3.0      611
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64
# 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: condition, dtype: int64
# 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# Name: grade, dtype: int64
# 1300    212
# 1010    210
# 1200    206
# 1220    192
# 1140    184
# 1400    180
# 1060    178
# 1180    177
# 1340    176
# 1250    174
# Name: sqft_above, dtype: int64
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
# 400.0       184
# 1000.0      148
# 900.0       142
# 300.0       142
# Name: sqft_basement, dtype: int64
# 2014    559
# 2006    453
# 2005    450
# 2004    433
# 2003    420
# 2007    417
# 1977    417
# 1978    387
# 1968    381
# 2008    367
# Name: yr_built, dtype: int64
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
# 2000.0       29
# 2005.0       29
# 1990.0       22
# 2004.0       22
# 2009.0       21
# Name: yr_renovated, dtype: int64
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
# 98042    547
# 98034    545
# 98118    507
# 98023    499
# 98006    498
# Name: zipcode, dtype: int64
# 47.6624    17
# 47.5491    17
# 47.5322    17
# 47.6846    17
# 47.6711    16
# 47.6886    16
# 47.6955    16
# 47.6647    15
# 47.6904    15
# 47.6860    15
# Name: lat, dtype: int64
# -122.290    115
# -122.300    111
# -122.362    104
# -122.291    100
# -122.372     99
# -122.363     99
# -122.288     98
# -122.357     96
# -122.284     95
# -122.172     94
# Name: long, dtype: int64
# 1540    197
# 1440    195
# 1560    192
# 1500    180
# 1460    169
# 1580    167
# 1610    166
# 1800    166
# 1720    166
# 1620    164
# Name: sqft_living15, dtype: int64
# 5000    427
# 4000    356
# 6000    288
# 7200    210
# 4800    145
# 7500    142
# 8400    116
# 4500    111
# 3600    111
# 5100    109
# Name: sqft_lot15, dtype: int64

# %% [markdown]
# sqft_basement has ? as a placement holder value

# %% [markdown]
# ## Further exploration - Histograms and Scatter Plots

# %%
df_subset1 = df.drop(columns=["id", "date"], axis = 1)
df_subset1.hist(figsize  = [30, 30])
plt.show()

# %% [markdown]
# Helping us get to know the data better, nothing looks too out of the ordinary here
#
# yr_renovated used 0 as a value for 'never renovated' which will make that data less useful unless addressed
#
# Worth noting that some of these distrubutions look more normal than others, will be useful when deciding later which parameters to include in the model, and which we might want to scale/normalise

# %%
df.price.hist(figsize = [10,10])
plt.show()

# %% [markdown]
# Price is positively squewed, so it will be worth taking the logPrice to make our final model more accurate

# %%
for x in ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']:
    df.plot.scatter(x,'price')
    
#sqft_basement not included as it still has placement value ?

# %% [markdown]
# Some of these are clearly categorical, worth noting as they will need addressing to include them in our model!

# %% [markdown]
# These outliers stood out to us:

# %%
#property with 33 bedrooms

df.loc[df["bedrooms"]==33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895  6/25/2014  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0  ...      7        1040
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 15856          580.0     1947           0.0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
#
# [1 rows x 21 columns]

# %%
#property with 9 bedrooms and 7.5 bathrooms

df.loc[(df["bedrooms"]==9)&(df['bathrooms']==7.5)]
# Out:
#              id       date     price  bedrooms  bathrooms  sqft_living  \
# 8537  424049043  8/11/2014  450000.0         9        7.5         4050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 8537      6504     2.0         0.0   0.0  ...      7        4050
#
#       sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 8537            0.0     1996           0.0    98144  47.5923 -122.301
#
#       sqft_living15  sqft_lot15
# 8537           1448        3866
#
# [1 rows x 21 columns]

# %%
#property with floor area of more than 13K sqft

df.loc[df["sqft_living"]>13000]
# Out:
#                id      date      price  bedrooms  bathrooms  sqft_living  \
# 12764  1225069038  5/5/2014  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12764    307752     3.0         0.0   4.0  ...     12        9410
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 12764         4130.0     1999           0.0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12764           4850      217800
#
# [1 rows x 21 columns]

# %%
#property with lot area of more than 1.6mil sqft

df.loc[df["sqft_lot"] > 1600000]
# Out:
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 1717  1020069017  3/27/2015  700000.0         4        1.0         1300
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1717   1651359     1.0         0.0   3.0  ...      6        1300
#
#       sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 1717            0.0     1920           0.0    98022  47.2313 -122.023
#
#       sqft_living15  sqft_lot15
# 1717           2560      425581
#
# [1 rows x 21 columns]

# %%
#nearest 15 neighbors' average lot area of more than 800K sqft

df.loc[df["sqft_lot15"] > 800000]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 9705    225079036   1/7/2015   937500.0         4        4.0         5545
# 20436  1125079111  4/15/2015  1600000.0         4        5.5         6530
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 9705     871200     2.0         0.0   0.0  ...     11        3605
# 20436    871200     2.0         0.0   2.0  ...     11        6530
#
#        sqft_basement yr_built  yr_renovated  zipcode     lat     long  \
# 9705          1940.0     2003           0.0    98014  47.676 -121.882
# 20436            0.0     2008           0.0    98014  47.664 -121.878
#
#        sqft_living15  sqft_lot15
# 9705            3420      871200
# 20436           1280      858132
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Total Findings

# %% [markdown]
# Columns:
#
# 1- 'waterfront' and 'view' columns have null values that need dealing with
#
# 2 - We need to work on the ?s in the basement situation and check that the two square foots add to total sqr foot
#
# 3 - 'yr_renovated' 0.0 needs addressing, reassign zeros to yr_built, and has null values
#
#
# Outliers:
#
# 1 - 33 bedroom house for 600k
#
# 2 - 9 bedroom 7.5 bathroom house, for 450k in central Seattle zipcode with mean 600k
#
# 3 - sqft_living =  13540 for 2.28mil in the outskirts
#
# 4 - sqft_lot = 1651359 for 700k
#
# 5 - Two sqft_lot_15 = ~800000 which are nearly twice as large as any others in 20,000 dataset

# %% [markdown]
# ## Dealing with columns and their nulls

# %%
df_test = df.copy()
df_test['waterfront'].fillna(value=2, inplace=True) #use 2 as placeholder fo NaN
df_test.groupby('waterfront')['price'].describe()
# Out:
#               count          mean           std       min       25%  \
# waterfront
# 0.0         19075.0  5.326420e+05  3.449592e+05   78000.0  320000.0
# 1.0           146.0  1.717215e+06  1.145385e+06  285000.0  827500.0
# 2.0          2376.0  5.294301e+05  3.250794e+05   80000.0  322875.0
#
#                   50%        75%        max
# waterfront
# 0.0          450000.0   638600.0  7700000.0
# 1.0         1510000.0  2282500.0  7060000.0
# 2.0          445000.0   649612.5  3200000.0

# %% [markdown]
# This shows us that the null values for the waterfront column closely align to the values for no waterfront view.
#
# This is our justification for reassigning the null value to zero, instead of to the mean or median

# %%
df['waterfront'].fillna(value=0, inplace=True)
df['waterfront'].value_counts()
# Out:
# 0.0    21451
# 1.0      146
# Name: waterfront, dtype: int64

# %% [markdown]
# Waterfront column cleaned!

# %%
df_test = df.copy()
df_test['view'].fillna(value=10, inplace=True) #use 10 as placeholder fo NaN
df_test.groupby('view')['price'].describe()
# Out:
#         count          mean            std       min       25%        50%  \
# view
# 0.0   19422.0  4.968061e+05  287419.959567   78000.0  311525.0   432500.0
# 1.0     330.0  8.133733e+05  512776.626107  217000.0  498250.0   691944.0
# 2.0     957.0  7.913904e+05  510385.693444  169317.0  485000.0   675000.0
# 3.0     508.0  9.732852e+05  613898.399842  154000.0  558000.0   802500.0
# 4.0     317.0  1.452466e+06  930747.701932  252000.0  815000.0  1180000.0
# 10.0     63.0  6.219582e+05  680927.087594  144000.0  322475.0   480000.0
#
#             75%        max
# view
# 0.0    600000.0  5570000.0
# 1.0    923750.0  3650000.0
# 2.0    938000.0  7060000.0
# 3.0   1260000.0  7700000.0
# 4.0   1850000.0  6890000.0
# 10.0   679000.0  5300000.0

# %% [markdown]
# This shows us that the null values for the view column fairly closely align to the values for zero views
#
# This is our justification for reassigning the null value to zero, instead of to the mean or median

# %%
df['view'].fillna(value=0, inplace=True)

# %% [markdown]
# View column cleaned!

# %% [markdown]
# yr_renovated column has many values that are 0.0, ie not renovated. There is no harm in reassigning these values to be equal to the year the house was built. We can apply the same assumption for the null values.

# %%
#placeholder yr_built for 0 and NaN
def proxy_yr_renovated(x):
    if ((x["yr_renovated"] == 0.0)| (np.isnan(x["yr_renovated"]))):
        return x["yr_built"]
    else:
        return x["yr_renovated"]

df["yr_renovated"] = df.apply(lambda x: proxy_yr_renovated(x), axis = 1)

df["yr_renovated"] = df["yr_renovated"].astype('int64')

df["yr_renovated"].tail()
# Out:
# 21592    2009
# 21593    2014
# 21594    2009
# 21595    2004
# 21596    2008
# Name: yr_renovated, dtype: int64

# %%
plt.figure(figsize = [10,5])
plt.scatter(df['yr_renovated'], df['price'])

# %% [markdown]
# Next, we will address the ? in the basement column.
# We will replicate column basement into a new column (basement2).
# We will add a check_flr column to check if above + basement2 = living.
# We will check to see if above + basement2 != living occurs when there are ?'s or occurs throughout the data.
# We will reassign all the incorrect basement values to be living - above.

# %%
#copy basement (basement2): placeholder 0 for ?, change dtype to float
df["sqft_basement2"] = df.sqft_basement
df["sqft_basement2"].replace(to_replace = "?", value = 0, inplace = True) 
df["sqft_basement2"] = df["sqft_basement2"].astype(dtype = "float64") 
df.loc[df["sqft_basement"] == "?"].head()
# Out:
#              id       date     price  bedrooms  bathrooms  sqft_living  \
# 6    1321400060  6/27/2014  257500.0         3       2.25         1715
# 18     16000397  12/5/2014  189000.0         2       1.00         1200
# 42   7203220400   7/7/2014  861990.0         5       2.75         3595
# 79   1531000030  3/23/2015  720000.0         4       2.50         3450
# 112  2525310310  9/16/2014  272500.0         3       1.75         1540
#
#      sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 6        6819     2.0         0.0   0.0  ...        1715              ?
# 18       9850     1.0         0.0   0.0  ...        1200              ?
# 42       5639     2.0         0.0   0.0  ...        3595              ?
# 79      39683     2.0         0.0   0.0  ...        3450              ?
# 112     12600     1.0         0.0   0.0  ...        1160              ?
#
#      yr_built yr_renovated  zipcode      lat     long  sqft_living15  \
# 6        1995         1995    98003  47.3097 -122.327           2238
# 18       1921         1921    98002  47.3089 -122.210           1060
# 42       2014         2014    98053  47.6848 -122.016           3625
# 79       2002         2002    98010  47.3420 -122.025           3350
# 112      1980         1980    98038  47.3624 -122.031           1540
#
#      sqft_lot15  sqft_basement2
# 6          6819             0.0
# 18         5095             0.0
# 42         5639             0.0
# 79        39750             0.0
# 112       11656             0.0
#
# [5 rows x 22 columns]

# %%
#added check_flr column to check if above + basement2 = living
df["check_flr"] = pd.Series(df["sqft_above"] + df["sqft_basement2"] == df["sqft_living"])
df.loc[df["check_flr"] == False]['sqft_basement'].value_counts()
#all false are those with 0 as placeholder. we can conclude that above+ basement = living
# Out:
# ?    170
# Name: sqft_basement, dtype: int64

# %%
#replace basement with living less above
df["sqft_basement"] =  df["sqft_living"] - df["sqft_above"]
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0         0.0   0.0  ...              0      1955
# 1      7242     2.0         0.0   0.0  ...            400      1951
# 2     10000     1.0         0.0   0.0  ...              0      1933
# 3      5000     1.0         0.0   0.0  ...            910      1965
# 4      8080     1.0         0.0   0.0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0          1955    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2          1933    98028  47.7379 -122.233           2720        8062
# 3          1965    98136  47.5208 -122.393           1360        5000
# 4          1987    98074  47.6168 -122.045           1800        7503
#
#    sqft_basement2  check_flr
# 0             0.0       True
# 1           400.0       True
# 2             0.0       True
# 3           910.0       True
# 4             0.0       True
#
# [5 rows x 23 columns]

# %%
#remove basement2 and check_flr
df.drop(columns = ["check_flr", "sqft_basement2"], inplace = True)
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         0.0   0.0  ...      7        1180              0
# 1      7242     2.0         0.0   0.0  ...      7        2170            400
# 2     10000     1.0         0.0   0.0  ...      6         770              0
# 3      5000     1.0         0.0   0.0  ...      7        1050            910
# 4      8080     1.0         0.0   0.0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955          1955    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933          1933    98028  47.7379 -122.233           2720
# 3      1965          1965    98136  47.5208 -122.393           1360
# 4      1987          1987    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# We have found all the houses where the sqft_above + sqft_basement doesn't equal sqft_living. It only happens when there are ? involved. In those cases, we have reassigned the ? to be the correct values, so that they satify the equation!

# %% [markdown]
# ## Dealing with outliers

# %%
df.loc[df["bedrooms"]==33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895  6/25/2014  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0  ...      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15856            580      1947          1947    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
#
# [1 rows x 21 columns]

# %%
df.loc[df["sqft_living"]==1620].sort_values(by = 'bedrooms', ascending = False)
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895   6/25/2014  640000.0        33       1.75         1620
# 11089  9542840570    4/1/2015  305000.0         4       2.50         1620
# 5323    254000545  10/23/2014  385000.0         4       2.50         1620
# 5765   5248800250   4/27/2015  375000.0         4       2.00         1620
# 9276   3856904610   10/2/2014  485000.0         4       1.00         1620
# ...           ...         ...       ...       ...        ...          ...
# 20139  3629960680   9/26/2014  395000.0         2       2.25         1620
# 15012  1323089056  11/10/2014  439000.0         2       1.75         1620
# 9228   3524039144   10/7/2014  700000.0         2       1.00         1620
# 6244   8850000509   9/23/2014  525000.0         2       1.50         1620
# 2786   3416600111   3/23/2015  545000.0         2       1.50         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0  ...      7        1040
# 11089      4000     2.0         0.0   0.0  ...      7        1620
# 5323       5280     2.0         0.0   0.0  ...      7        1620
# 5765       4600     2.0         0.0   0.0  ...      7        1620
# 9276       4080     1.5         0.0   0.0  ...      7        1620
# ...         ...     ...         ...   ...  ...    ...         ...
# 20139      1841     2.0         0.0   0.0  ...      8        1540
# 15012    113862     1.5         0.0   0.0  ...      7        1620
# 9228       9855     1.0         0.0   4.0  ...      8        1320
# 6244       1444     2.0         0.0   0.0  ...      9        1080
# 2786       3760     2.0         0.0   0.0  ...      7        1170
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15856            580      1947          1947    98103  47.6878 -122.331
# 11089              0      2008          2008    98038  47.3661 -122.020
# 5323               0      1924          1924    98146  47.5132 -122.384
# 5765               0      1909          1909    98108  47.5533 -122.307
# 9276               0      1923          1923    98105  47.6696 -122.324
# ...              ...       ...           ...      ...      ...      ...
# 20139             80      2004          2004    98029  47.5483 -122.004
# 15012              0      1995          1995    98045  47.4821 -121.719
# 9228             300      1948          1948    98136  47.5264 -122.384
# 6244             540      2007          2007    98144  47.5892 -122.309
# 2786             450      1924          1924    98144  47.6012 -122.291
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
# 11089           1580        3780
# 5323            1590        5280
# 5765            1620        4500
# 9276            1760        4080
# ...              ...         ...
# 20139           1530        1831
# 15012           1560       54806
# 9228            1820        7700
# 6244            1660        1642
# 2786            2130        4000
#
# [99 rows x 21 columns]

# %% [markdown]
# By looking at all the other similarly sized houses (by sqft) we can clearly see that the 33 bedroom house is a weird exception. We have a good arguement for just changing it to a 3 bedroom house. We also looked at the Latitude and Logitude and it was not a 3 bedroom house in that location, it was no bigger than any other houses near it.

# %% [markdown]
# Enough evidence to change the bedroom to a 3 bedroom house!

# %%
df.iloc[15856, df.columns.get_loc('bedrooms')] = 3

df.iloc[15856]
# Out:
# id               2402100895
# date              6/25/2014
# price                640000
# bedrooms                  3
# bathrooms              1.75
# sqft_living            1620
# sqft_lot               6000
# floors                    1
# waterfront                0
# view                      0
# condition                 5
# grade                     7
# sqft_above             1040
# sqft_basement           580
# yr_built               1947
# yr_renovated           1947
# zipcode               98103
# lat                 47.6878
# long               -122.331
# sqft_living15          1330
# sqft_lot15             4700
# Name: 15856, dtype: object

# %% [markdown]
# 9-bedroom and  7.5-bathroom house in Seattle city centre 450k, except mean is 600k and its by far the biggest house in the neighbourhood.
# Drop it, those numbers make no sense!

# %%
df.loc[df["bathrooms"] > 7].sort_values(by = "price")
#index 8537 potential outlier
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 8537    424049043   8/11/2014   450000.0         9       7.50         4050
# 12764  1225069038    5/5/2014  2280000.0         7       8.00        13540
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 8537       6504     2.0         0.0   0.0  ...      7        4050
# 12764    307752     3.0         0.0   4.0  ...     12        9410
# 9245      31374     2.0         0.0   4.0  ...     13        8860
# 7245      27600     2.5         0.0   3.0  ...     13        8570
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 8537               0      1996          1996    98144  47.5923 -122.301
# 12764           4130      1999          1999    98053  47.6675 -121.986
# 9245            1030      2001          2001    98039  47.6305 -122.240
# 7245            3480      1910          1987    98102  47.6298 -122.323
#
#        sqft_living15  sqft_lot15
# 8537            1448        3866
# 12764           4850      217800
# 9245            4540       42730
# 7245            3940        8800
#
# [4 rows x 21 columns]

# %%
df.drop(index = 8537, axis = 0, inplace = True)
df.loc[df["bathrooms"] > 7].sort_values(by = "price")
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 12764  1225069038    5/5/2014  2280000.0         7       8.00        13540
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12764    307752     3.0         0.0   4.0  ...     12        9410
# 9245      31374     2.0         0.0   4.0  ...     13        8860
# 7245      27600     2.5         0.0   3.0  ...     13        8570
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12764           4130      1999          1999    98053  47.6675 -121.986
# 9245            1030      2001          2001    98039  47.6305 -122.240
# 7245            3480      1910          1987    98102  47.6298 -122.323
#
#        sqft_living15  sqft_lot15
# 12764           4850      217800
# 9245            4540       42730
# 7245            3940        8800
#
# [3 rows x 21 columns]

# %% [markdown]
# We also drop a sqft_living = 13540 for $2.28mil in the outskirts and a sqft_lot = 1651359 for 700k, although they may be priced correctly. It's not the end of the world to lose a few outliers.
# Logically, we weren't sure how there could be 2 values of sqft_lot15 that were so massive (800000>), so we removed them too.
# Same arguement applies for them, they will skew the model.

# %%
df.loc[df["sqft_living"] > 13000].sort_values(by = "price")
# Out:
#                id      date      price  bedrooms  bathrooms  sqft_living  \
# 12764  1225069038  5/5/2014  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12764    307752     3.0         0.0   4.0  ...     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12764           4130      1999          1999    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12764           4850      217800
#
# [1 rows x 21 columns]

# %%
df.loc[df['zipcode'] == 98053].sort_values(by = "sqft_living", ascending = False)

#index 12764 potential outlier.
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 12764  1225069038    5/5/2014  2280000.0         7       8.00        13540
# 6495   2626069030    2/9/2015  1940000.0         4       5.75         7220
# 5054   1125069153   8/22/2014  1530000.0         4       3.50         5990
# 10901  2954400310   9/15/2014  1770000.0         4       3.50         5440
# 19548  1625069101    7/7/2014  1360000.0         4       3.00         5430
# ...           ...         ...        ...       ...        ...          ...
# 17088  8807810660    3/2/2015   350000.0         3       1.00         1150
# 15275   203900920   7/15/2014   340000.0         3       2.00         1130
# 11138  8807300570  12/29/2014   399950.0         3       1.00         1040
# 15865  8807300130  12/17/2014   330000.0         3       1.00          910
# 7010    203100460   9/24/2014   400000.0         1       1.00          530
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12764    307752     3.0         0.0   4.0  ...     12        9410
# 6495     223462     2.0         0.0   4.0  ...     12        6220
# 5054     111078     2.0         0.0   0.0  ...     11        5990
# 10901     38900     2.0         0.0   0.0  ...     12        5440
# 19548    108900     2.0         0.0   0.0  ...     10        5430
# ...         ...     ...         ...   ...  ...    ...         ...
# 17088     12877     1.0         0.0   0.0  ...      6        1150
# 15275      9879     2.0         0.0   0.0  ...      6        1130
# 11138      9600     1.0         0.0   0.0  ...      7        1040
# 15865     10240     1.0         0.0   0.0  ...      6         910
# 7010      13679     1.0         0.0   0.0  ...      6         530
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12764           4130      1999          1999    98053  47.6675 -121.986
# 6495            1000      2000          2000    98053  47.7097 -122.013
# 5054               0      2004          2004    98053  47.6670 -121.994
# 10901              0      1990          1990    98053  47.6605 -122.069
# 19548              0      1987          1987    98053  47.6582 -122.038
# ...              ...       ...           ...      ...      ...      ...
# 17088              0      1970          1970    98053  47.6614 -122.056
# 15275              0      1996          1996    98053  47.6350 -121.964
# 11138              0      1978          1978    98053  47.6738 -122.063
# 15865              0      1969          1969    98053  47.6729 -122.064
# 7010               0      1949          1949    98053  47.6422 -121.954
#
#        sqft_living15  sqft_lot15
# 12764           4850      217800
# 6495            2680        7593
# 5054            4690      118918
# 10901           4830       41313
# 19548           3170      107076
# ...              ...         ...
# 17088           1490       12150
# 15275           1900       14907
# 11138           1370       10889
# 15865           1140       10720
# 7010            1930       20624
#
# [403 rows x 21 columns]

# %%
df.drop(index = 12764, axis = 0, inplace = True)
df.loc[df["sqft_living"] > 13000].sort_values(by = "price")
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[df["sqft_lot"] > 1300000].sort_values(by = "price")
# Out:
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 1717  1020069017  3/27/2015  700000.0         4        1.0         1300
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1717   1651359     1.0         0.0   3.0  ...      6        1300
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1717              0      1920          1920    98022  47.2313 -122.023
#
#       sqft_living15  sqft_lot15
# 1717           2560      425581
#
# [1 rows x 21 columns]

# %%
df.loc[df['zipcode'] == 98022].sort_values(by = "sqft_lot", ascending = False)

#index 1717 potential outlier.
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 1717   1020069017  3/27/2015  700000.0         4       1.00         1300
# 12993   619079096   4/6/2015  750000.0         3       2.50         2350
# 17811  2220069003  2/23/2015  425000.0         3       2.75         1360
# 12906   820079043  8/19/2014  428000.0         3       1.75         1580
# 9201   3420069055  12/3/2014  350000.0         4       2.25         1570
# ...           ...        ...       ...       ...        ...          ...
# 4605   8141300300   2/7/2015  293000.0         4       2.50         2019
# 2029   2420069017  3/24/2015  152900.0         1       1.00          900
# 3523   8005100025  9/19/2014  195000.0         3       1.00         1510
# 19159  2420069220  12/3/2014  209000.0         3       1.00         1320
# 15404  2420069242  9/25/2014  175000.0         2       1.00          740
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1717    1651359     1.0         0.0   3.0  ...      6        1300
# 12993    715690     1.5         0.0   0.0  ...      9        2350
# 17811    542322     1.0         0.0   2.0  ...      7        1140
# 12906    507038     1.0         0.0   2.0  ...      7        1580
# 9201     499571     1.0         0.0   3.0  ...      7        1570
# ...         ...     ...         ...   ...  ...    ...         ...
# 4605       4435     2.0         0.0   3.0  ...      8        2019
# 2029       4368     1.0         0.0   0.0  ...      6         900
# 3523       4350     1.5         0.0   0.0  ...      6        1510
# 19159      3954     1.5         0.0   0.0  ...      6        1320
# 15404      3434     1.0         0.0   0.0  ...      6         740
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1717               0      1920          1920    98022  47.2313 -122.023
# 12993              0      1979          1979    98022  47.1622 -121.971
# 17811            220      1955          1955    98022  47.2069 -122.024
# 12906              0      1985          1985    98022  47.2303 -121.936
# 9201               0      1972          1972    98022  47.1808 -122.023
# ...              ...       ...           ...      ...      ...      ...
# 4605               0      2008          2008    98022  47.1958 -121.974
# 2029               0      1915          1950    98022  47.2107 -121.990
# 3523               0      1913          1913    98022  47.2052 -121.987
# 19159              0      1912          2014    98022  47.2020 -121.994
# 15404              0      1920          1920    98022  47.2088 -121.992
#
#        sqft_living15  sqft_lot15
# 1717            2560      425581
# 12993           1280      325393
# 17811           1700       60548
# 12906           2040      210394
# 9201            1700      181708
# ...              ...         ...
# 4605            1950        4800
# 2029            1290        5000
# 3523            1210        5500
# 19159           1270        5184
# 15404           1160        6000
#
# [233 rows x 21 columns]

# %%
df.drop(index = 1717, axis = 0, inplace = True)
df.loc[df["sqft_lot"] > 1300000].sort_values(by = "price")
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# We also spotted a few outliers in the sqft_lot15 scatter plot, and want to investigate them further

# %%
pd.DataFrame(df.sort_values(by = "sqft_lot15", ascending = False)[['price','sqft_lot15']]).head(10)

#potential outlier 9705, 20436
# Out:
#            price  sqft_lot15
# 9705    937500.0      871200
# 20436  1600000.0      858132
# 13451   790000.0      560617
# 8655    549950.0      438213
# 3797    637000.0      434728
# 19141   858000.0      422967
# 6685   2000000.0      411962
# 21415   800000.0      392040
# 15606   180000.0      392040
# 17645   370000.0      386812

# %%
df.loc[df['sqft_lot15'] > 800000].sort_values(by = 'price', ascending = False)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 20436  1125079111  4/15/2015  1600000.0         4        5.5         6530
# 9705    225079036   1/7/2015   937500.0         4        4.0         5545
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 20436    871200     2.0         0.0   2.0  ...     11        6530
# 9705     871200     2.0         0.0   0.0  ...     11        3605
#
#        sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 20436              0      2008          2008    98014  47.664 -121.878
# 9705            1940      2003          2003    98014  47.676 -121.882
#
#        sqft_living15  sqft_lot15
# 20436           1280      858132
# 9705            3420      871200
#
# [2 rows x 21 columns]

# %%
df.drop(index = [20436, 9705], axis = 0, inplace = True)
df.loc[df['sqft_lot15'] > 800000].sort_values(by = 'price', ascending = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# We weren't sure how logically you could have only one or two houses with such a high sqft_lot15, when it is so dependant on its neighbours. So we decided we'd remove them just to be safe. Now we have clean enough data!

# %% [markdown]
# ## Some interesting questions

# %% [markdown]
# Apart from building a model to predict a house's price, we want to address a few things more in detail.

# %% [markdown]
# 1 - How much volatility was there in the housing market in Seattle in 2014/2015?

# %% [markdown]
# Houses that were sold and resold in this period increased in price how much?

# %% [markdown]
# 2 - "What year's houses were built the best?"

# %% [markdown]
# We would expect that in general, as houses get old, their condition would worsen. Is there a year/decade that bucks this trend, because theyre houses were built to withstand deterioration better?

# %% [markdown]
# 3 - "Is it worth adding another bathroom, assuming it costs $25,000 to do so?"

# %% [markdown]
# If all else is held steady in our model, will adding a bathroom increase price by 25k?
# Do houses in our data show an average increase of 25k if they have one more bathroom?

# %% [markdown]
# We will answer these questions later once we have an accurate model to help us!

# %% [markdown]
# # Gameplan for Model

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016287  0.003107   0.006399    -0.010990 -0.134623
# price         -0.016287  1.000000  0.315649   0.525663     0.702146  0.089031
# bedrooms       0.003107  0.315649  1.000000   0.526594     0.593504  0.031650
# bathrooms      0.006399  0.525663  0.526594   1.000000     0.755004  0.087430
# sqft_living   -0.010990  0.702146  0.593504   0.755004     1.000000  0.173658
# sqft_lot      -0.134623  0.089031  0.031650   0.087430     0.173658  1.000000
# floors         0.018895  0.256306  0.183187   0.502635     0.353561 -0.006206
# waterfront    -0.003625  0.264538 -0.002008   0.063906     0.105208  0.023156
# view           0.012347  0.392729  0.079922   0.184938     0.280145  0.069023
# condition     -0.023913  0.036314  0.023733  -0.126193    -0.059006 -0.009651
# grade          0.008636  0.667634  0.366267   0.666292     0.763594  0.117648
# sqft_above    -0.009712  0.604792  0.491939   0.685272     0.875836  0.186124
# sqft_basement -0.004593  0.322721  0.308794   0.281719     0.432552  0.011546
# yr_built       0.021781  0.053615  0.160543   0.507740     0.318500  0.056928
# yr_renovated   0.020167  0.097265  0.169645   0.533084     0.339646  0.056084
# zipcode       -0.008366 -0.053092 -0.158982  -0.205383    -0.200169 -0.133064
# lat           -0.001777  0.306713 -0.011815   0.023600     0.051523 -0.088142
# long           0.021106  0.021233  0.136484   0.224653     0.240644  0.236668
# sqft_living15 -0.002392  0.585096  0.404683   0.570794     0.757884  0.149728
# sqft_lot15    -0.140899  0.079455  0.029713   0.081447     0.178441  0.705022
#
#                  floors  waterfront      view  condition     grade  \
# id             0.018895   -0.003625  0.012347  -0.023913  0.008636
# price          0.256306    0.264538  0.392729   0.036314  0.667634
# bedrooms       0.183187   -0.002008  0.079922   0.023733  0.366267
# bathrooms      0.502635    0.063906  0.184938  -0.126193  0.666292
# sqft_living    0.353561    0.105208  0.280145  -0.059006  0.763594
# sqft_lot      -0.006206    0.023156  0.069023  -0.009651  0.117648
# floors         1.000000    0.020820  0.027892  -0.263957  0.458495
# waterfront     0.020820    1.000000  0.380961   0.016642  0.082909
# view           0.027892    0.380961  1.000000   0.045711  0.248635
# condition     -0.263957    0.016642  0.045711   1.000000 -0.146696
# grade          0.458495    0.082909  0.248635  -0.146696  1.000000
# sqft_above     0.524030    0.072069  0.164130  -0.158788  0.756329
# sqft_basement -0.247550    0.083014  0.272933   0.174575  0.166743
# yr_built       0.489069   -0.024482 -0.054549  -0.361480  0.447712
# yr_renovated   0.500611   -0.006884 -0.026665  -0.390160  0.459204
# zipcode       -0.059498    0.028917  0.085566   0.002885 -0.185575
# lat            0.048980   -0.012158  0.006484  -0.014930  0.113188
# long           0.125692   -0.037615 -0.078637  -0.105812  0.199734
# sqft_living15  0.279815    0.083891  0.278396  -0.093035  0.713979
# sqft_lot15    -0.014526    0.032724  0.069731  -0.001827  0.118841
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# id              -0.009712      -0.004593  0.021781      0.020167 -0.008366
# price            0.604792       0.322721  0.053615      0.097265 -0.053092
# bedrooms         0.491939       0.308794  0.160543      0.169645 -0.158982
# bathrooms        0.685272       0.281719  0.507740      0.533084 -0.205383
# sqft_living      0.875836       0.432552  0.318500      0.339646 -0.200169
# sqft_lot         0.186124       0.011546  0.056928      0.056084 -0.133064
# floors           0.524030      -0.247550  0.489069      0.500611 -0.059498
# waterfront       0.072069       0.083014 -0.024482     -0.006884  0.028917
# view             0.164130       0.272933 -0.054549     -0.026665  0.085566
# condition       -0.158788       0.174575 -0.361480     -0.390160  0.002885
# grade            0.756329       0.166743  0.447712      0.459204 -0.185575
# sqft_above       1.000000      -0.056279  0.424385      0.433856 -0.261943
# sqft_basement   -0.056279       1.000000 -0.133927     -0.107873  0.075255
# yr_built         0.424385      -0.133927  1.000000      0.926382 -0.347297
# yr_renovated     0.433856      -0.107873  0.926382      1.000000 -0.324056
# zipcode         -0.261943       0.075255 -0.347297     -0.324056  1.000000
# lat             -0.001914       0.110166 -0.148742     -0.137817  0.266800
# long             0.344562      -0.145868  0.410020      0.386346 -0.564146
# sqft_living15    0.732791       0.198903  0.326485      0.325650 -0.279258
# sqft_lot15       0.191651       0.011114  0.072129      0.070930 -0.150976
#
#                     lat      long  sqft_living15  sqft_lot15
# id            -0.001777  0.021106      -0.002392   -0.140899
# price          0.306713  0.021233       0.585096    0.079455
# bedrooms      -0.011815  0.136484       0.404683    0.029713
# bathrooms      0.023600  0.224653       0.570794    0.081447
# sqft_living    0.051523  0.240644       0.757884    0.178441
# sqft_lot      -0.088142  0.236668       0.149728    0.705022
# floors         0.048980  0.125692       0.279815   -0.014526
# waterfront    -0.012158 -0.037615       0.083891    0.032724
# view           0.006484 -0.078637       0.278396    0.069731
# condition     -0.014930 -0.105812      -0.093035   -0.001827
# grade          0.113188  0.199734       0.713979    0.118841
# sqft_above    -0.001914  0.344562       0.732791    0.191651
# sqft_basement  0.110166 -0.145868       0.198903    0.011114
# yr_built      -0.148742  0.410020       0.326485    0.072129
# yr_renovated  -0.137817  0.386346       0.325650    0.070930
# zipcode        0.266800 -0.564146      -0.279258   -0.150976
# lat            1.000000 -0.135522       0.048620   -0.091946
# long          -0.135522  1.000000       0.335436    0.261187
# sqft_living15  0.048620  0.335436       1.000000    0.190111
# sqft_lot15    -0.091946  0.261187       0.190111    1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap((((df_subset1.corr() >= 0.7) | (df_subset1.corr() <= -0.7)) & (df_subset1.corr() != 1)), center=0)

# %%
display(df.head())
display(df.columns)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         0.0   0.0  ...      7        1180              0
# 1      7242     2.0         0.0   0.0  ...      7        2170            400
# 2     10000     1.0         0.0   0.0  ...      6         770              0
# 3      5000     1.0         0.0   0.0  ...      7        1050            910
# 4      8080     1.0         0.0   0.0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955          1955    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933          1933    98028  47.7379 -122.233           2720
# 3      1965          1965    98136  47.5208 -122.393           1360
# 4      1987          1987    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize = [10,5])
plt.scatter(df['zipcode'].astype("category").unique(), df.groupby('zipcode')['price'].mean())

# %%
df.groupby('zipcode')['price'].mean().sort_values(ascending = False).head(10)
# Out:
# zipcode
# 98039    2.161300e+06
# 98004    1.356524e+06
# 98040    1.194874e+06
# 98112    1.096239e+06
# 98102    8.996077e+05
# 98109    8.800778e+05
# 98105    8.632289e+05
# 98006    8.599386e+05
# 98119    8.497148e+05
# 98005    8.102897e+05
# Name: price, dtype: float64

# %% [markdown]
# Given how different pricing  expensive houses near the waterfront is vs pricing cheap homes in the suburbs is, we think it is smart to split our model up. We have subsetted our zipcodes to those waterfront zipcodes which we assumed are most desireable. They are nearest all the marina restaurants and entertainment! We are trying to find a split which allows us to price better, and this is the first we will try!

# %% [markdown]
# # ![4aab31ce95d5b8474fd2cc063f334178.jpg](attachment:4aab31ce95d5b8474fd2cc063f334178.jpg)

# %%
kingcounty = folium.Map(location= (47.628646,-122.324193), zoom_start=12)
seattle = folium.Marker(location= (47.608013, -122.335167), icon=folium.Icon(color='blue'))
seattle. add_to(kingcounty)
marina = folium.Marker(location= (47.6087207, -122.258875), icon=folium.Icon(color='green'))
marina.add_to(kingcounty)
kingcounty.save(outfile='map.html')
kingcounty

##blue is city centre, green is centre of desirable zipcodes
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Scaling and Normalisation

# %% [markdown]
# To be able to run a linear regression effectively, some of this data needs to be scaled and normalised. We noted already that price would have to be normlized as we need data that looks more like the normal distrubution!

# %%
#create a subset of predictors to be scaled or normalised
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df_pred = df[['price','sqft_living','sqft_lot','condition', 'grade', 'sqft_above', 'sqft_basement',
              'yr_built', 'yr_renovated','date', 'zipcode','sqft_living15', 'sqft_lot15']]
df_pred.hist(column = ['price','sqft_living','sqft_lot','condition', 'grade', 'sqft_above', 'sqft_basement',
              'yr_built', 'yr_renovated','date', 'zipcode','sqft_living15', 'sqft_lot15'], figsize  = [20, 20])
plt.show()

# %%
df_pred.describe()
# Out:
#               price   sqft_living      sqft_lot     condition         grade  \
# count  2.159200e+04  21592.000000  2.159200e+04  21592.000000  21592.000000
# mean   5.401453e+05   2079.369489  1.493117e+04      3.409874      7.657512
# std    3.671369e+05    913.974780  3.898092e+04      0.650585      1.172459
# min    7.800000e+04    370.000000  5.200000e+02      1.000000      3.000000
# 25%    3.220000e+05   1430.000000  5.040000e+03      3.000000      7.000000
# 50%    4.500000e+05   1910.000000  7.617000e+03      3.000000      7.000000
# 75%    6.450000e+05   2550.000000  1.067975e+04      4.000000      8.000000
# max    7.700000e+06  12050.000000  1.164794e+06      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21592.000000   21592.000000  21592.000000  21592.000000  21592.000000
# mean    1787.858049     291.511439   1970.996388   1972.942293  98077.958457
# std      825.355762     441.791944     29.373587     28.943828     53.512216
# min      370.000000       0.000000   1900.000000   1900.000000  98001.000000
# 25%     1190.000000       0.000000   1951.000000   1954.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000   1977.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000   1999.000000  98118.000000
# max     8860.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#        sqft_living15     sqft_lot15
# count   21592.000000   21592.000000
# mean     1986.452436   12651.170341
# std       684.925411   25825.978176
# min       399.000000     651.000000
# 25%      1490.000000    5100.000000
# 50%      1840.000000    7620.000000
# 75%      2360.000000   10080.000000
# max      6210.000000  560617.000000

# %%
#transform categorical predictor: yr_built, yr_renovated

# %%
display(df_pred["yr_built"].nunique(dropna = False))
display(df_pred["yr_built"].describe())
# Out:
# 116
# count    21592.000000
# mean      1970.996388
# std         29.373587
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %%
df_pred["yr_built_scaled"] = df_pred["yr_built"].map(lambda x: x - 1899)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pred.head(10)
# Out:
#        price  sqft_living  sqft_lot  condition  grade  sqft_above  \
# 0   221900.0         1180      5650          3      7        1180
# 1   538000.0         2570      7242          3      7        2170
# 2   180000.0          770     10000          3      6         770
# 3   604000.0         1960      5000          5      7        1050
# 4   510000.0         1680      8080          3      8        1680
# 5  1230000.0         5420    101930          3     11        3890
# 6   257500.0         1715      6819          3      7        1715
# 7   291850.0         1060      9711          3      7        1060
# 8   229500.0         1780      7470          3      7        1050
# 9   323000.0         1890      6560          3      7        1890
#
#    sqft_basement  yr_built  yr_renovated        date  zipcode  sqft_living15  \
# 0              0      1955          1955  10/13/2014    98178           1340
# 1            400      1951          1991   12/9/2014    98125           1690
# 2              0      1933          1933   2/25/2015    98028           2720
# 3            910      1965          1965   12/9/2014    98136           1360
# 4              0      1987          1987   2/18/2015    98074           1800
# 5           1530      2001          2001   5/12/2014    98053           4760
# 6              0      1995          1995   6/27/2014    98003           2238
# 7              0      1963          1963   1/15/2015    98198           1650
# 8            730      1960          1960   4/15/2015    98146           1780
# 9              0      2003          2003   3/12/2015    98038           2390
#
#    sqft_lot15  yr_built_scaled
# 0        5650               56
# 1        7639               52
# 2        8062               34
# 3        5000               66
# 4        7503               88
# 5      101930              102
# 6        6819               96
# 7        9711               64
# 8        8113               61
# 9        7570              104

# %%
df_pred['yr_renovated_scaled'] = df_pred["yr_renovated"].map(lambda x: x - 1899)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pred.tail(10)
# Out:
#            price  sqft_living  sqft_lot  condition  grade  sqft_above  \
# 21587   507250.0         2270      5536          3      8        2270
# 21588   429000.0         1490      1126          3      8        1490
# 21589   610685.0         2520      6023          3      9        2520
# 21590  1010000.0         3510      7200          3      9        2600
# 21591   475000.0         1310      1294          3      8        1180
# 21592   360000.0         1530      1131          3      8        1530
# 21593   400000.0         2310      5813          3      8        2310
# 21594   402101.0         1020      1350          3      7        1020
# 21595   400000.0         1600      2388          3      8        1600
# 21596   325000.0         1020      1076          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated        date  zipcode  \
# 21587              0      2003          2003   8/25/2014    98065
# 21588              0      2014          2014   1/26/2015    98144
# 21589              0      2014          2014  10/14/2014    98056
# 21590            910      2009          2009   3/26/2015    98136
# 21591            130      2008          2008   2/19/2015    98116
# 21592              0      2009          2009   5/21/2014    98103
# 21593              0      2014          2014   2/23/2015    98146
# 21594              0      2009          2009   6/23/2014    98144
# 21595              0      2004          2004   1/16/2015    98027
# 21596              0      2008          2008  10/15/2014    98144
#
#        sqft_living15  sqft_lot15  yr_built_scaled  yr_renovated_scaled
# 21587           2270        5731              104                  104
# 21588           1400        1230              115                  115
# 21589           2520        6023              115                  115
# 21590           2050        6200              110                  110
# 21591           1330        1265              109                  109
# 21592           1530        1509              110                  110
# 21593           1830        7200              115                  115
# 21594           1020        2007              110                  110
# 21595           1410        1287              105                  105
# 21596           1020        1357              109                  109

# %%
df_pred[['sqft_living','sqft_lot','condition', 'grade', 'sqft_above', 'sqft_basement',
              'yr_built_scaled', 'yr_renovated_scaled', 'zipcode','sqft_living15', 'sqft_lot15']].hist(figsize  = [20, 20])
plt.show()

# %%
#Normalise some of the predictors by taking the log 
#This will mean they are look closer to the normal distribution, and are therefore more useful in linear regression 

for x in ['price','sqft_living', 'sqft_lot','sqft_living15', 'sqft_lot15']:
     df_pred[x+"_log"] = df_pred[x].map(lambda x: np.log(x))
df_pred.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       price  sqft_living  sqft_lot  condition  grade  sqft_above  \
# 0  221900.0         1180      5650          3      7        1180
# 1  538000.0         2570      7242          3      7        2170
# 2  180000.0          770     10000          3      6         770
# 3  604000.0         1960      5000          5      7        1050
# 4  510000.0         1680      8080          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated        date  zipcode  sqft_living15  \
# 0              0      1955          1955  10/13/2014    98178           1340
# 1            400      1951          1991   12/9/2014    98125           1690
# 2              0      1933          1933   2/25/2015    98028           2720
# 3            910      1965          1965   12/9/2014    98136           1360
# 4              0      1987          1987   2/18/2015    98074           1800
#
#    sqft_lot15  yr_built_scaled  yr_renovated_scaled  price_log  \
# 0        5650               56                   56  12.309982
# 1        7639               52                   92  13.195614
# 2        8062               34                   34  12.100712
# 3        5000               66                   66  13.311329
# 4        7503               88                   88  13.142166
#
#    sqft_living_log  sqft_lot_log  sqft_living15_log  sqft_lot15_log
# 0         7.073270      8.639411           7.200425        8.639411
# 1         7.851661      8.887653           7.432484        8.941022
# 2         6.646391      9.210340           7.908387        8.994917
# 3         7.580700      8.517193           7.215240        8.517193
# 4         7.426549      8.997147           7.495542        8.923058

# %%
df_pred[['price_log','sqft_living_log','sqft_lot_log','condition', 'grade','yr_built_scaled', 'yr_renovated_scaled','sqft_living15_log', 'sqft_lot15_log']].hist(figsize  = [20, 20])
plt.show()

# %%
#Zipcodes arent themselves useful measures, but they provide a nice way to subset data
#We will create some columns of mean/mode values in particular zipcodes
#This is a good indictator of how nice a neighbourhood is 

display(df_pred.groupby(df_pred['zipcode']).grade.apply(lambda x: x.mean()).head())
display(df_pred.groupby(df_pred['zipcode']).grade.apply(lambda x: x.mode()[0]).head())

display(df_pred.groupby(df_pred['zipcode']).condition.apply(lambda x: x.mean()).head())
display(df_pred.groupby(df_pred['zipcode']).condition.apply(lambda x: x.mode()[0]).head())
# Out:
# zipcode
# 98001    7.296399
# 98002    6.693467
# 98003    7.542857
# 98004    8.687697
# 98005    8.488095
# Name: grade, dtype: float64
# zipcode
# 98001    7
# 98002    7
# 98003    7
# 98004    8
# 98005    8
# Name: grade, dtype: int64
# zipcode
# 98001    3.335180
# 98002    3.743719
# 98003    3.371429
# 98004    3.495268
# 98005    3.696429
# Name: condition, dtype: float64
# zipcode
# 98001    3
# 98002    4
# 98003    3
# 98004    3
# 98005    4
# Name: condition, dtype: int64

# %%
#add mean and mode grade per zipcode, as they might be useful predictors

mode_grade = df_pred.groupby(df_pred['zipcode']).grade.apply(lambda x: x.mode()[0])
mean_grade = df_pred.groupby(df_pred['zipcode']).grade.apply(lambda x: x.mean())

#add mean and mode condition per zipcode, for the same reason

mean_condition = df_pred.groupby(df_pred['zipcode']).condition.apply(lambda x: x.mean())
mode_condition = df_pred.groupby(df_pred['zipcode']).condition.apply(lambda x: x.mode()[0])


df_zipcode = pd.DataFrame({'zipcode': df_pred.groupby(df_pred['zipcode']).grade.apply(lambda x: x.mode()[0]).index,
                           'mean_grade_per_zipcode': mean_grade,
                           'mode_grade_per_zipcode': mode_grade,
                           'mean_condition_per_zipcode': mean_condition,
                           'mode_condition_per_zipcode': mode_condition,})
df_zipcode.drop(columns = "zipcode", axis = 1, inplace = True)
df_zipcode
# Out:
#          mean_grade_per_zipcode  mode_grade_per_zipcode  \
# zipcode
# 98001                  7.296399                       7
# 98002                  6.693467                       7
# 98003                  7.542857                       7
# 98004                  8.687697                       8
# 98005                  8.488095                       8
# ...                         ...                     ...
# 98177                  7.976471                       8
# 98178                  6.816794                       7
# 98188                  7.036765                       7
# 98198                  7.103571                       7
# 98199                  8.012618                       7
#
#          mean_condition_per_zipcode  mode_condition_per_zipcode
# zipcode
# 98001                      3.335180                           3
# 98002                      3.743719                           4
# 98003                      3.371429                           3
# 98004                      3.495268                           3
# 98005                      3.696429                           4
# ...                             ...                         ...
# 98177                      3.494118                           3
# 98178                      3.320611                           3
# 98188                      3.330882                           3
# 98198                      3.442857                           3
# 98199                      3.507886                           3
#
# [70 rows x 4 columns]

# %%
import datetime
df_pred['date_formatted'] = pd.to_datetime(df_pred['date'])
df_pred['yr_sold'] = df_pred['date_formatted'].dt.year
df_pred.head()
# Out:
#       price  sqft_living  sqft_lot  condition  grade  sqft_above  \
# 0  221900.0         1180      5650          3      7        1180
# 1  538000.0         2570      7242          3      7        2170
# 2  180000.0          770     10000          3      6         770
# 3  604000.0         1960      5000          5      7        1050
# 4  510000.0         1680      8080          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated        date  ...  sqft_lot15  \
# 0              0      1955          1955  10/13/2014  ...        5650
# 1            400      1951          1991   12/9/2014  ...        7639
# 2              0      1933          1933   2/25/2015  ...        8062
# 3            910      1965          1965   12/9/2014  ...        5000
# 4              0      1987          1987   2/18/2015  ...        7503
#
#    yr_built_scaled  yr_renovated_scaled  price_log  sqft_living_log  \
# 0               56                   56  12.309982         7.073270
# 1               52                   92  13.195614         7.851661
# 2               34                   34  12.100712         6.646391
# 3               66                   66  13.311329         7.580700
# 4               88                   88  13.142166         7.426549
#
#    sqft_lot_log  sqft_living15_log  sqft_lot15_log  date_formatted  yr_sold
# 0      8.639411           7.200425        8.639411      2014-10-13     2014
# 1      8.887653           7.432484        8.941022      2014-12-09     2014
# 2      9.210340           7.908387        8.994917      2015-02-25     2015
# 3      8.517193           7.215240        8.517193      2014-12-09     2014
# 4      8.997147           7.495542        8.923058      2015-02-18     2015
#
# [5 rows x 22 columns]

# %%
df_pred['age_yr_sold'] = df_pred['yr_sold'] - df_pred['yr_built']

df_pred.head()
# Out:
#       price  sqft_living  sqft_lot  condition  grade  sqft_above  \
# 0  221900.0         1180      5650          3      7        1180
# 1  538000.0         2570      7242          3      7        2170
# 2  180000.0          770     10000          3      6         770
# 3  604000.0         1960      5000          5      7        1050
# 4  510000.0         1680      8080          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated        date  ...  yr_built_scaled  \
# 0              0      1955          1955  10/13/2014  ...               56
# 1            400      1951          1991   12/9/2014  ...               52
# 2              0      1933          1933   2/25/2015  ...               34
# 3            910      1965          1965   12/9/2014  ...               66
# 4              0      1987          1987   2/18/2015  ...               88
#
#    yr_renovated_scaled  price_log  sqft_living_log  sqft_lot_log  \
# 0                   56  12.309982         7.073270      8.639411
# 1                   92  13.195614         7.851661      8.887653
# 2                   34  12.100712         6.646391      9.210340
# 3                   66  13.311329         7.580700      8.517193
# 4                   88  13.142166         7.426549      8.997147
#
#    sqft_living15_log  sqft_lot15_log  date_formatted  yr_sold  age_yr_sold
# 0           7.200425        8.639411      2014-10-13     2014           59
# 1           7.432484        8.941022      2014-12-09     2014           63
# 2           7.908387        8.994917      2015-02-25     2015           82
# 3           7.215240        8.517193      2014-12-09     2014           49
# 4           7.495542        8.923058      2015-02-18     2015           28
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize = [20,20])
df_pred.plot.scatter('age_yr_sold','price')
plt.xticks(np.arange(-20, 150, step=10))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_pred["age_yr_sold"].value_counts().tail()
# Out:
#  113    28
#  115    26
#  81     23
#  80     21
# -1      12
# Name: age_yr_sold, dtype: int64

# %%
df_pred.loc[df_pred["age_yr_sold"] < 0]
#realisitically, some houses are able to be bought before building completion, so this isn't too out of the ordinary
# Out:
#           price  sqft_living  sqft_lot  condition  grade  sqft_above  \
# 1761   597326.0         3570      8250          3     10        2860
# 2685   385195.0          710      6000          3      6         710
# 7519   614285.0         2730      6401          3      8        2730
# 8032   455000.0         1200      1259          3      8        1000
# 14475  500000.0         1570      1269          3      9        1280
# 17084  350000.0         1380      3600          3      8        1380
# 19789  455000.0         1320      1014          3      9        1320
# 20754  357000.0         2990      9240          3      8        2990
# 20836  595000.0         3730      4560          3      9        2760
# 20947  230000.0         1040      1264          3      9         900
# 21246  559000.0         1650       960          3      8        1350
# 21356  490000.0         4460      2975          3     10        3280
#
#        sqft_basement  yr_built  yr_renovated        date  ...  \
# 1761             710      2015          2015   6/25/2014  ...
# 2685               0      2015          2015  10/29/2014  ...
# 7519               0      2015          2015  12/31/2014  ...
# 8032             200      2015          2015   6/24/2014  ...
# 14475            290      2015          2015   8/26/2014  ...
# 17084              0      2015          2015   6/17/2014  ...
# 19789              0      2015          2015    8/1/2014  ...
# 20754              0      2015          2015   8/28/2014  ...
# 20836            970      2015          2015    7/9/2014  ...
# 20947            140      2015          2015   7/31/2014  ...
# 21246            300      2015          2015  11/25/2014  ...
# 21356           1180      2015          2015   5/20/2014  ...
#
#        yr_built_scaled  yr_renovated_scaled  price_log  sqft_living_log  \
# 1761               116                  116  13.300218         8.180321
# 2685               116                  116  12.861505         6.565265
# 7519               116                  116  13.328214         7.912057
# 8032               116                  116  13.028053         7.090077
# 14475              116                  116  13.122363         7.358831
# 17084              116                  116  12.765688         7.229839
# 19789              116                  116  13.028053         7.185387
# 20754              116                  116  12.785491         8.003029
# 20836              116                  116  13.296317         8.224164
# 20947              116                  116  12.345835         6.946976
# 21246              116                  116  13.233905         7.408531
# 21356              116                  116  13.102161         8.402904
#
#        sqft_lot_log  sqft_living15_log  sqft_lot15_log  date_formatted  \
# 1761       9.017968           7.709757        9.210340      2014-06-25
# 2685       8.699515           7.272398        8.476371      2014-10-29
# 7519       8.764210           7.832014        8.720297      2014-12-31
# 8032       7.138073           7.185387        7.524021      2014-06-24
# 14475      7.145984           7.358831        8.699515      2014-08-26
# 17084      8.188689           7.299797        8.188689      2014-06-17
# 19789      6.921658           7.229839        7.309881      2014-08-01
# 20754      9.131297           7.585789        9.804220      2014-08-28
# 20836      8.425078           7.495542        8.425078      2014-07-09
# 20947      7.142037           7.207860        8.006368      2014-07-31
# 21246      6.866933           7.408531        8.006368      2014-11-25
# 21356      7.997999           7.820038        8.350194      2014-05-20
#
#        yr_sold  age_yr_sold
# 1761      2014           -1
# 2685      2014           -1
# 7519      2014           -1
# 8032      2014           -1
# 14475     2014           -1
# 17084     2014           -1
# 19789     2014           -1
# 20754     2014           -1
# 20836     2014           -1
# 20947     2014           -1
# 21246     2014           -1
# 21356     2014           -1
#
# [12 rows x 23 columns]

# %%
df_pred.drop(columns = ['sqft_living', 'sqft_lot', 'condition','grade', 'sqft_above',
                         'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15',
                         'sqft_lot15','price', 'date'], inplace = True)

df_pred.head()
# Out:
#    yr_built_scaled  yr_renovated_scaled  price_log  sqft_living_log  \
# 0               56                   56  12.309982         7.073270
# 1               52                   92  13.195614         7.851661
# 2               34                   34  12.100712         6.646391
# 3               66                   66  13.311329         7.580700
# 4               88                   88  13.142166         7.426549
#
#    sqft_lot_log  sqft_living15_log  sqft_lot15_log date_formatted  yr_sold  \
# 0      8.639411           7.200425        8.639411     2014-10-13     2014
# 1      8.887653           7.432484        8.941022     2014-12-09     2014
# 2      9.210340           7.908387        8.994917     2015-02-25     2015
# 3      8.517193           7.215240        8.517193     2014-12-09     2014
# 4      8.997147           7.495542        8.923058     2015-02-18     2015
#
#    age_yr_sold
# 0           59
# 1           63
# 2           82
# 3           49
# 4           28

# %%
df_final = pd.concat([df, df_pred], axis =1, join = 'outer') # add scaled / normalised predictors

# %%
df_final.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built_scaled  \
# 0      5650     1.0         0.0   0.0  ...               56
# 1      7242     2.0         0.0   0.0  ...               52
# 2     10000     1.0         0.0   0.0  ...               34
# 3      5000     1.0         0.0   0.0  ...               66
# 4      8080     1.0         0.0   0.0  ...               88
#
#    yr_renovated_scaled  price_log  sqft_living_log  sqft_lot_log  \
# 0                   56  12.309982         7.073270      8.639411
# 1                   92  13.195614         7.851661      8.887653
# 2                   34  12.100712         6.646391      9.210340
# 3                   66  13.311329         7.580700      8.517193
# 4                   88  13.142166         7.426549      8.997147
#
#    sqft_living15_log  sqft_lot15_log  date_formatted  yr_sold  age_yr_sold
# 0           7.200425        8.639411      2014-10-13     2014           59
# 1           7.432484        8.941022      2014-12-09     2014           63
# 2           7.908387        8.994917      2015-02-25     2015           82
# 3           7.215240        8.517193      2014-12-09     2014           49
# 4           7.495542        8.923058      2015-02-18     2015           28
#
# [5 rows x 31 columns]

# %%
df_final = df_final.join(df_zipcode, on = "zipcode", how = "left") # add df_zipcode

# %%
df_final.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_lot_log  sqft_living15_log  \
# 0      5650     1.0         0.0   0.0  ...      8.639411           7.200425
# 1      7242     2.0         0.0   0.0  ...      8.887653           7.432484
# 2     10000     1.0         0.0   0.0  ...      9.210340           7.908387
# 3      5000     1.0         0.0   0.0  ...      8.517193           7.215240
# 4      8080     1.0         0.0   0.0  ...      8.997147           7.495542
#
#    sqft_lot15_log  date_formatted  yr_sold  age_yr_sold  \
# 0        8.639411      2014-10-13     2014           59
# 1        8.941022      2014-12-09     2014           63
# 2        8.994917      2015-02-25     2015           82
# 3        8.517193      2014-12-09     2014           49
# 4        8.923058      2015-02-18     2015           28
#
#    mean_grade_per_zipcode  mode_grade_per_zipcode  mean_condition_per_zipcode  \
# 0                6.816794                       7                    3.320611
# 1                7.176039                       7                    3.342298
# 2                7.611307                       7                    3.300353
# 3                7.403042                       7                    3.395437
# 4                8.709751                       9                    3.126984
#
#    mode_condition_per_zipcode
# 0                           3
# 1                           3
# 2                           3
# 3                           3
# 4                           3
#
# [5 rows x 35 columns]

# %%
#lets check the age again, just to be sure

display(df_final.loc[df_final["age_yr_sold"] < 0]) #negative age

df_final[df_final.duplicated(subset=["id"], keep="first")] #resold properties

#check whether these properties were resold:
df_final.loc[df_final["age_yr_sold"] < 0].index.isin(df_final[df_final.duplicated(subset=["id"], keep="first")].index)

#these properties were not resold.  we can assume these were sold during the preselling period. \
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 1761   1832100030   6/25/2014  597326.0         4       4.00         3570
# 2685   3076500830  10/29/2014  385195.0         1       1.00          710
# 7519   9520900210  12/31/2014  614285.0         5       2.75         2730
# 8032   1250200495   6/24/2014  455000.0         2       1.50         1200
# 14475  2770601530   8/26/2014  500000.0         2       2.25         1570
# 17084  9126100346   6/17/2014  350000.0         3       2.00         1380
# 19789  9126100765    8/1/2014  455000.0         3       1.75         1320
# 20754  9310300160   8/28/2014  357000.0         5       2.50         2990
# 20836  1257201420    7/9/2014  595000.0         4       3.25         3730
# 20947  6058600220   7/31/2014  230000.0         3       1.50         1040
# 21246  5694500840  11/25/2014  559000.0         2       3.00         1650
# 21356  6169901185   5/20/2014  490000.0         5       3.50         4460
#
#        sqft_lot  floors  waterfront  view  ...  sqft_lot_log  \
# 1761       8250     2.0         0.0   0.0  ...      9.017968
# 2685       6000     1.5         0.0   0.0  ...      8.699515
# 7519       6401     2.0         0.0   0.0  ...      8.764210
# 8032       1259     2.0         0.0   0.0  ...      7.138073
# 14475      1269     2.0         0.0   0.0  ...      7.145984
# 17084      3600     3.0         0.0   0.0  ...      8.188689
# 19789      1014     3.0         0.0   0.0  ...      6.921658
# 20754      9240     2.0         0.0   0.0  ...      9.131297
# 20836      4560     2.0         0.0   0.0  ...      8.425078
# 20947      1264     2.0         0.0   0.0  ...      7.142037
# 21246       960     3.0         0.0   0.0  ...      6.866933
# 21356      2975     3.0         0.0   2.0  ...      7.997999
#
#        sqft_living15_log  sqft_lot15_log  date_formatted  yr_sold  \
# 1761            7.709757        9.210340      2014-06-25     2014
# 2685            7.272398        8.476371      2014-10-29     2014
# 7519            7.832014        8.720297      2014-12-31     2014
# 8032            7.185387        7.524021      2014-06-24     2014
# 14475           7.358831        8.699515      2014-08-26     2014
# 17084           7.299797        8.188689      2014-06-17     2014
# 19789           7.229839        7.309881      2014-08-01     2014
# 20754           7.585789        9.804220      2014-08-28     2014
# 20836           7.495542        8.425078      2014-07-09     2014
# 20947           7.207860        8.006368      2014-07-31     2014
# 21246           7.408531        8.006368      2014-11-25     2014
# 21356           7.820038        8.350194      2014-05-20     2014
#
#        age_yr_sold  mean_grade_per_zipcode  mode_grade_per_zipcode  \
# 1761            -1                8.960993                       8
# 2685            -1                7.456140                       7
# 7519            -1                8.069597                       7
# 8032            -1                7.456140                       7
# 14475           -1                8.012618                       7
# 17084           -1                7.744828                       8
# 19789           -1                7.744828                       8
# 20754           -1                7.123732                       7
# 20836           -1                7.410299                       7
# 20947           -1                7.456140                       7
# 21246           -1                7.410299                       7
# 21356           -1                8.021739                       8
#
#        mean_condition_per_zipcode  mode_condition_per_zipcode
# 1761                     3.787234                           4
# 2685                     3.505848                           3
# 7519                     3.307692                           3
# 8032                     3.505848                           3
# 14475                    3.507886                           3
# 17084                    3.306897                           3
# 19789                    3.306897                           3
# 20754                    3.541582                           3
# 20836                    3.483389                           3
# 20947                    3.505848                           3
# 21246                    3.483389                           3
# 21356                    3.375000                           3
#
# [12 rows x 35 columns]
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
#use 0 as a placeholder for age

def age_neg(x):
    if x["age_yr_sold"] < 0:
        return 0
    else:
        return x["age_yr_sold"]


df_final["age_yr_sold"] = df_final.apply(lambda x: age_neg(x), axis = 1)

df_final.loc[df_final["age_yr_sold"]< 0]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, yr_built_scaled, yr_renovated_scaled, price_log, sqft_living_log, sqft_lot_log, sqft_living15_log, sqft_lot15_log, date_formatted, yr_sold, age_yr_sold, mean_grade_per_zipcode, mode_grade_per_zipcode, mean_condition_per_zipcode, mode_condition_per_zipcode]
# Index: []
#
# [0 rows x 35 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21592 entries, 0 to 21596
# Data columns (total 35 columns):
# id                            21592 non-null int64
# date                          21592 non-null object
# price                         21592 non-null float64
# bedrooms                      21592 non-null int64
# bathrooms                     21592 non-null float64
# sqft_living                   21592 non-null int64
# sqft_lot                      21592 non-null int64
# floors                        21592 non-null float64
# waterfront                    21592 non-null float64
# view                          21592 non-null float64
# condition                     21592 non-null int64
# grade                         21592 non-null int64
# sqft_above                    21592 non-null int64
# sqft_basement                 21592 non-null int64
# yr_built                      21592 non-null int64
# yr_renovated                  21592 non-null int64
# zipcode                       21592 non-null int64
# lat                           21592 non-null float64
# long                          21592 non-null float64
# sqft_living15                 21592 non-null int64
# sqft_lot15                    21592 non-null int64
# yr_built_scaled               21592 non-null int64
# yr_renovated_scaled           21592 non-null int64
# price_log                     21592 non-null float64
# sqft_living_log               21592 non-null float64
# sqft_lot_log                  21592 non-null float64
# sqft_living15_log             21592 non-null float64
# sqft_lot15_log                21592 non-null float64
# date_formatted                21592 non-null datetime64[ns]
# yr_sold                       21592 non-null int64
# age_yr_sold                   21592 non-null int64
# mean_grade_per_zipcode        21592 non-null float64
# mode_grade_per_zipcode        21592 non-null int64
# mean_condition_per_zipcode    21592 non-null float64
# mode_condition_per_zipcode    21592 non-null int64
# dtypes: datetime64[ns](1), float64(14), int64(19), object(1)
# memory usage: 5.9+ MB

# %%
df_working = df_final[['id', 'zipcode','waterfront', 'view', 'condition', 'grade','lat', 'long', 'yr_built_scaled',
                       'yr_renovated_scaled', 'price_log', 'sqft_living_log', 'sqft_lot_log',
                       'sqft_living15_log', 'sqft_lot15_log','age_yr_sold', 'mean_grade_per_zipcode',
                       'mode_grade_per_zipcode','mean_condition_per_zipcode', 'mode_condition_per_zipcode']]

df_working.head()
# Out:
#            id  zipcode  waterfront  view  condition  grade      lat     long  \
# 0  7129300520    98178         0.0   0.0          3      7  47.5112 -122.257
# 1  6414100192    98125         0.0   0.0          3      7  47.7210 -122.319
# 2  5631500400    98028         0.0   0.0          3      6  47.7379 -122.233
# 3  2487200875    98136         0.0   0.0          5      7  47.5208 -122.393
# 4  1954400510    98074         0.0   0.0          3      8  47.6168 -122.045
#
#    yr_built_scaled  yr_renovated_scaled  price_log  sqft_living_log  \
# 0               56                   56  12.309982         7.073270
# 1               52                   92  13.195614         7.851661
# 2               34                   34  12.100712         6.646391
# 3               66                   66  13.311329         7.580700
# 4               88                   88  13.142166         7.426549
#
#    sqft_lot_log  sqft_living15_log  sqft_lot15_log  age_yr_sold  \
# 0      8.639411           7.200425        8.639411           59
# 1      8.887653           7.432484        8.941022           63
# 2      9.210340           7.908387        8.994917           82
# 3      8.517193           7.215240        8.517193           49
# 4      8.997147           7.495542        8.923058           28
#
#    mean_grade_per_zipcode  mode_grade_per_zipcode  mean_condition_per_zipcode  \
# 0                6.816794                       7                    3.320611
# 1                7.176039                       7                    3.342298
# 2                7.611307                       7                    3.300353
# 3                7.403042                       7                    3.395437
# 4                8.709751                       9                    3.126984
#
#    mode_condition_per_zipcode
# 0                           3
# 1                           3
# 2                           3
# 3                           3
# 4                           3

# %%
df_working[['waterfront', 'view', 'condition', 'grade','lat', 'long', 'yr_built_scaled','yr_renovated_scaled',
           'price_log', 'sqft_living_log', 'sqft_lot_log', 'sqft_living15_log', 'sqft_lot15_log','age_yr_sold',
           'mean_grade_per_zipcode','mode_grade_per_zipcode','mean_condition_per_zipcode', 'mode_condition_per_zipcode']].hist(figsize = [30,30])
plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# ## Universal Model

# %%
df_working.columns
# Out:
# Index(['id', 'zipcode', 'waterfront', 'view', 'condition', 'grade', 'lat',
#        'long', 'yr_built_scaled', 'yr_renovated_scaled', 'price_log',
#        'sqft_living_log', 'sqft_lot_log', 'sqft_living15_log',
#        'sqft_lot15_log', 'age_yr_sold', 'mean_grade_per_zipcode',
#        'mode_grade_per_zipcode', 'mean_condition_per_zipcode',
#        'mode_condition_per_zipcode'],
#       dtype='object')

# %%
df_working[['price_log','sqft_living_log', 'sqft_lot_log', 'sqft_living15_log',
       'sqft_lot15_log','waterfront', 'view', 'condition', 'grade', 'lat',
       'long', 'yr_built_scaled', 'yr_renovated_scaled', 'age_yr_sold', 'mean_grade_per_zipcode',
       'mode_grade_per_zipcode', 'mean_condition_per_zipcode',
       'mode_condition_per_zipcode']].corr()
# Out:
#                             price_log  sqft_living_log  sqft_lot_log  \
# price_log                    1.000000         0.674613      0.136982
# sqft_living_log              0.674613         1.000000      0.325170
# sqft_lot_log                 0.136982         0.325170      1.000000
# sqft_living15_log            0.607173         0.747214      0.363789
# sqft_lot15_log               0.122325         0.302042      0.918308
# waterfront                   0.170816         0.079015      0.072594
# view                         0.344077         0.244118      0.119764
# condition                    0.039097        -0.049285      0.074045
# grade                        0.703569         0.742762      0.183223
# lat                          0.448937         0.038380     -0.149448
# long                         0.050218         0.256694      0.375433
# yr_built_scaled              0.080356         0.349431     -0.007567
# yr_renovated_scaled          0.121842         0.370149     -0.012338
# age_yr_sold                 -0.080278        -0.349888      0.007423
# mean_grade_per_zipcode       0.567191         0.405658      0.176762
# mode_grade_per_zipcode       0.401540         0.299556      0.140384
# mean_condition_per_zipcode   0.105689        -0.045803     -0.072643
# mode_condition_per_zipcode   0.073923         0.054747      0.105767
#
#                             sqft_living15_log  sqft_lot15_log  waterfront  \
# price_log                            0.607173        0.122325    0.170816
# sqft_living_log                      0.747214        0.302042    0.079015
# sqft_lot_log                         0.363789        0.918308    0.072594
# sqft_living15_log                    1.000000        0.373717    0.076543
# sqft_lot15_log                       0.373717        1.000000    0.081844
# waterfront                           0.076543        0.081844    1.000000
# view                                 0.262227        0.117222    0.380961
# condition                           -0.089249        0.080295    0.016642
# grade                                0.689261        0.183669    0.082909
# lat                                  0.043602       -0.143952   -0.012158
# long                                 0.337981        0.376189   -0.037615
# yr_built_scaled                      0.333945        0.018427   -0.024482
# yr_renovated_scaled                  0.332334        0.013908   -0.006884
# age_yr_sold                         -0.334262       -0.018567    0.024400
# mean_grade_per_zipcode               0.518914        0.187717    0.003879
# mode_grade_per_zipcode               0.387252        0.150654    0.011630
# mean_condition_per_zipcode          -0.078499       -0.065027    0.042617
# mode_condition_per_zipcode           0.060027        0.116192    0.073511
#
#                                 view  condition     grade       lat      long  \
# price_log                   0.344077   0.039097  0.703569  0.448937  0.050218
# sqft_living_log             0.244118  -0.049285  0.742762  0.038380  0.256694
# sqft_lot_log                0.119764   0.074045  0.183223 -0.149448  0.375433
# sqft_living15_log           0.262227  -0.089249  0.689261  0.043602  0.337981
# sqft_lot15_log              0.117222   0.080295  0.183669 -0.143952  0.376189
# waterfront                  0.380961   0.016642  0.082909 -0.012158 -0.037615
# view                        1.000000   0.045711  0.248635  0.006484 -0.078637
# condition                   0.045711   1.000000 -0.146696 -0.014930 -0.105812
# grade                       0.248635  -0.146696  1.000000  0.113188  0.199734
# lat                         0.006484  -0.014930  0.113188  1.000000 -0.135522
# long                       -0.078637  -0.105812  0.199734 -0.135522  1.000000
# yr_built_scaled            -0.054549  -0.361480  0.447712 -0.148742  0.410020
# yr_renovated_scaled        -0.026665  -0.390160  0.459204 -0.137817  0.386346
# age_yr_sold                 0.054561   0.360722 -0.448171  0.148286 -0.410017
# mean_grade_per_zipcode      0.040341  -0.014746  0.484738  0.231304  0.412221
# mode_grade_per_zipcode      0.023560  -0.054608  0.382405  0.168938  0.318560
# mean_condition_per_zipcode  0.105999   0.254599 -0.028075 -0.044835 -0.412290
# mode_condition_per_zipcode  0.051925   0.114907  0.041190 -0.082858  0.007381
#
#                             yr_built_scaled  yr_renovated_scaled  age_yr_sold  \
# price_log                          0.080356             0.121842    -0.080278
# sqft_living_log                    0.349431             0.370149    -0.349888
# sqft_lot_log                      -0.007567            -0.012338     0.007423
# sqft_living15_log                  0.333945             0.332334    -0.334262
# sqft_lot15_log                     0.018427             0.013908    -0.018567
# waterfront                        -0.024482            -0.006884     0.024400
# view                              -0.054549            -0.026665     0.054561
# condition                         -0.361480            -0.390160     0.360722
# grade                              0.447712             0.459204    -0.448171
# lat                               -0.148742            -0.137817     0.148286
# long                               0.410020             0.386346    -0.410017
# yr_built_scaled                    1.000000             0.926382    -0.999873
# yr_renovated_scaled                0.926382             1.000000    -0.926374
# age_yr_sold                       -0.999873            -0.926374     1.000000
# mean_grade_per_zipcode             0.234778             0.236998    -0.235165
# mode_grade_per_zipcode             0.169393             0.170798    -0.169794
# mean_condition_per_zipcode        -0.240494            -0.224707     0.240457
# mode_condition_per_zipcode        -0.020460            -0.022235     0.020292
#
#                             mean_grade_per_zipcode  mode_grade_per_zipcode  \
# price_log                                 0.567191                0.401540
# sqft_living_log                           0.405658                0.299556
# sqft_lot_log                              0.176762                0.140384
# sqft_living15_log                         0.518914                0.387252
# sqft_lot15_log                            0.187717                0.150654
# waterfront                                0.003879                0.011630
# view                                      0.040341                0.023560
# condition                                -0.014746               -0.054608
# grade                                     0.484738                0.382405
# lat                                       0.231304                0.168938
# long                                      0.412221                0.318560
# yr_built_scaled                           0.234778                0.169393
# yr_renovated_scaled                       0.236998                0.170798
# age_yr_sold                              -0.235165               -0.169794
# mean_grade_per_zipcode                    1.000000                0.788890
# mode_grade_per_zipcode                    0.788890                1.000000
# mean_condition_per_zipcode               -0.057917               -0.214485
# mode_condition_per_zipcode                0.084974                0.007588
#
#                             mean_condition_per_zipcode  \
# price_log                                     0.105689
# sqft_living_log                              -0.045803
# sqft_lot_log                                 -0.072643
# sqft_living15_log                            -0.078499
# sqft_lot15_log                               -0.065027
# waterfront                                    0.042617
# view                                          0.105999
# condition                                     0.254599
# grade                                        -0.028075
# lat                                          -0.044835
# long                                         -0.412290
# yr_built_scaled                              -0.240494
# yr_renovated_scaled                          -0.224707
# age_yr_sold                                   0.240457
# mean_grade_per_zipcode                       -0.057917
# mode_grade_per_zipcode                       -0.214485
# mean_condition_per_zipcode                    1.000000
# mode_condition_per_zipcode                    0.451325
#
#                             mode_condition_per_zipcode
# price_log                                     0.073923
# sqft_living_log                               0.054747
# sqft_lot_log                                  0.105767
# sqft_living15_log                             0.060027
# sqft_lot15_log                                0.116192
# waterfront                                    0.073511
# view                                          0.051925
# condition                                     0.114907
# grade                                         0.041190
# lat                                          -0.082858
# long                                          0.007381
# yr_built_scaled                              -0.020460
# yr_renovated_scaled                          -0.022235
# age_yr_sold                                   0.020292
# mean_grade_per_zipcode                        0.084974
# mode_grade_per_zipcode                        0.007588
# mean_condition_per_zipcode                    0.451325
# mode_condition_per_zipcode                    1.000000

# %%
formula = "price_log~grade+sqft_lot_log+age_yr_sold+waterfront+view+mean_grade_per_zipcode"
model = ols(formula = formula, data = df_working).fit()
display(model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              price_log   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     7096.
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):               0.00
# Time:                        15:15:35   Log-Likelihood:                -5021.0
# No. Observations:               21592   AIC:                         1.006e+04
# Df Residuals:                   21585   BIC:                         1.011e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  8.6167      0.034    254.413      0.000       8.550       8.683
# grade                      0.2870      0.002    122.773      0.000       0.282       0.292
# sqft_lot_log              -0.0358      0.002    -15.040      0.000      -0.040      -0.031
# age_yr_sold                0.0049    8.1e-05     60.710      0.000       0.005       0.005
# waterfront                 0.3885      0.027     14.154      0.000       0.335       0.442
# view                       0.0974      0.003     31.486      0.000       0.091       0.103
# mean_grade_per_zipcode     0.3026      0.004     71.613      0.000       0.294       0.311
# ==============================================================================
# Omnibus:                      134.529   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.353
# Skew:                          -0.097   Prob(JB):                     5.08e-39
# Kurtosis:                       3.398   Cond. No.                         877.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(16, 8))

x = sns.regplot(y="price_log", x="grade", data=df_working)

# %%
df_working[["price_log","sqft_living_log","grade","view","mean_grade_per_zipcode"]].corr()
# Out:
#                         price_log  sqft_living_log     grade      view  \
# price_log                1.000000         0.674613  0.703569  0.344077
# sqft_living_log          0.674613         1.000000  0.742762  0.244118
# grade                    0.703569         0.742762  1.000000  0.248635
# view                     0.344077         0.244118  0.248635  1.000000
# mean_grade_per_zipcode   0.567191         0.405658  0.484738  0.040341
#
#                         mean_grade_per_zipcode
# price_log                             0.567191
# sqft_living_log                       0.405658
# grade                                 0.484738
# view                                  0.040341
# mean_grade_per_zipcode                1.000000

# %%
import scipy.stats as stats
residuals = model.resid
fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %% [markdown]
# Admittedly, grade and sqft_living_log have too high of a corrolation to include in a final model, but our qq plot looked pretty great!
# Potentially some cancelling out of multicollinearity going on here?

# %% [markdown]
# ## Model in the Waterfront Properties

# %%
#2 subsets

df_working1 = df_working.loc[(df_working["zipcode"] == 98039) 
                         | (df_working["zipcode"] == 98004)
                         | (df_working["zipcode"] == 98040)
                         | (df_working["zipcode"] == 98112)
                         | (df_working["zipcode"] == 98102)]

df_working1["zipcode"].unique()
# Out:
# array([98040, 98112, 98004, 98102, 98039])

# %%
df_working1[['price_log','sqft_living_log', 'sqft_lot_log', 'sqft_living15_log',
       'sqft_lot15_log','waterfront', 'view', 'condition', 'grade', 'lat',
       'long', 'yr_built_scaled', 'yr_renovated_scaled', 'age_yr_sold', 'mean_grade_per_zipcode',
       'mode_grade_per_zipcode', 'mean_condition_per_zipcode',
       'mode_condition_per_zipcode']].corr()
# Out:
#                             price_log  sqft_living_log  sqft_lot_log  \
# price_log                    1.000000         0.841153      0.554857
# sqft_living_log              0.841153         1.000000      0.550350
# sqft_lot_log                 0.554857         0.550350      1.000000
# sqft_living15_log            0.676752         0.661205      0.691765
# sqft_lot15_log               0.536637         0.507936      0.928025
# waterfront                   0.238951         0.140245      0.105847
# view                         0.387878         0.326653      0.299758
# condition                    0.050133         0.038518      0.187109
# grade                        0.763285         0.777852      0.352608
# lat                         -0.004254        -0.168285     -0.395901
# long                         0.258057         0.261518      0.699280
# yr_built_scaled              0.221231         0.232777      0.068247
# yr_renovated_scaled          0.271213         0.270954      0.097765
# age_yr_sold                 -0.220199        -0.232559     -0.067807
# mean_grade_per_zipcode       0.312414         0.309718      0.628203
# mode_grade_per_zipcode       0.264594         0.149225      0.200859
# mean_condition_per_zipcode   0.051578         0.207965      0.413107
# mode_condition_per_zipcode   0.008477         0.175934      0.357352
#
#                             sqft_living15_log  sqft_lot15_log  waterfront  \
# price_log                            0.676752        0.536637    0.238951
# sqft_living_log                      0.661205        0.507936    0.140245
# sqft_lot_log                         0.691765        0.928025    0.105847
# sqft_living15_log                    1.000000        0.711098    0.155340
# sqft_lot15_log                       0.711098        1.000000    0.131263
# waterfront                           0.155340        0.131263    1.000000
# view                                 0.410288        0.300873    0.368602
# condition                            0.176300        0.195911    0.045299
# grade                                0.544681        0.339358    0.113545
# lat                                 -0.270728       -0.401923   -0.106816
# long                                 0.378046        0.731235    0.056076
# yr_built_scaled                      0.082586        0.135348    0.011055
# yr_renovated_scaled                  0.113323        0.159780    0.023588
# age_yr_sold                         -0.082147       -0.134899   -0.011036
# mean_grade_per_zipcode               0.416134        0.661506    0.108281
# mode_grade_per_zipcode               0.155045        0.222016    0.014734
# mean_condition_per_zipcode           0.306702        0.421737    0.139396
# mode_condition_per_zipcode           0.271378        0.359238    0.144805
#
#                                 view  condition     grade       lat      long  \
# price_log                   0.387878   0.050133  0.763285 -0.004254  0.258057
# sqft_living_log             0.326653   0.038518  0.777852 -0.168285  0.261518
# sqft_lot_log                0.299758   0.187109  0.352608 -0.395901  0.699280
# sqft_living15_log           0.410288   0.176300  0.544681 -0.270728  0.378046
# sqft_lot15_log              0.300873   0.195911  0.339358 -0.401923  0.731235
# waterfront                  0.368602   0.045299  0.113545 -0.106816  0.056076
# view                        1.000000   0.034563  0.299220 -0.228702  0.125441
# condition                   0.034563   1.000000 -0.053813 -0.175148  0.073415
# grade                       0.299220  -0.053813  1.000000 -0.120959  0.137406
# lat                        -0.228702  -0.175148 -0.120959  1.000000 -0.467684
# long                        0.125441   0.073415  0.137406 -0.467684  1.000000
# yr_built_scaled             0.078748  -0.292246  0.430292 -0.237732  0.367348
# yr_renovated_scaled         0.108137  -0.354270  0.417120 -0.208544  0.356506
# age_yr_sold                -0.078870   0.291589 -0.430329  0.237933 -0.366779
# mean_grade_per_zipcode      0.201432   0.114386  0.216896 -0.531995  0.630333
# mode_grade_per_zipcode      0.014087  -0.028848  0.141607  0.131173  0.075291
# mean_condition_per_zipcode  0.248692   0.202064  0.122783 -0.849121  0.387819
# mode_condition_per_zipcode  0.256005   0.194084  0.116479 -0.862526  0.313714
#
#                             yr_built_scaled  yr_renovated_scaled  age_yr_sold  \
# price_log                          0.221231             0.271213    -0.220199
# sqft_living_log                    0.232777             0.270954    -0.232559
# sqft_lot_log                       0.068247             0.097765    -0.067807
# sqft_living15_log                  0.082586             0.113323    -0.082147
# sqft_lot15_log                     0.135348             0.159780    -0.134899
# waterfront                         0.011055             0.023588    -0.011036
# view                               0.078748             0.108137    -0.078870
# condition                         -0.292246            -0.354270     0.291589
# grade                              0.430292             0.417120    -0.430329
# lat                               -0.237732            -0.208544     0.237933
# long                               0.367348             0.356506    -0.366779
# yr_built_scaled                    1.000000             0.868576    -0.999896
# yr_renovated_scaled                0.868576             1.000000    -0.868854
# age_yr_sold                       -0.999896            -0.868854     1.000000
# mean_grade_per_zipcode             0.282992             0.289146    -0.282864
# mode_grade_per_zipcode             0.071947             0.095075    -0.072267
# mean_condition_per_zipcode         0.166599             0.157838    -0.166439
# mode_condition_per_zipcode         0.175449             0.158800    -0.175370
#
#                             mean_grade_per_zipcode  mode_grade_per_zipcode  \
# price_log                                 0.312414                0.264594
# sqft_living_log                           0.309718                0.149225
# sqft_lot_log                              0.628203                0.200859
# sqft_living15_log                         0.416134                0.155045
# sqft_lot15_log                            0.661506                0.222016
# waterfront                                0.108281                0.014734
# view                                      0.201432                0.014087
# condition                                 0.114386               -0.028848
# grade                                     0.216896                0.141607
# lat                                      -0.531995                0.131173
# long                                      0.630333                0.075291
# yr_built_scaled                           0.282992                0.071947
# yr_renovated_scaled                       0.289146                0.095075
# age_yr_sold                              -0.282864               -0.072267
# mean_grade_per_zipcode                    1.000000                0.652876
# mode_grade_per_zipcode                    0.652876                1.000000
# mean_condition_per_zipcode                0.566089               -0.142766
# mode_condition_per_zipcode                0.537027               -0.140010
#
#                             mean_condition_per_zipcode  \
# price_log                                     0.051578
# sqft_living_log                               0.207965
# sqft_lot_log                                  0.413107
# sqft_living15_log                             0.306702
# sqft_lot15_log                                0.421737
# waterfront                                    0.139396
# view                                          0.248692
# condition                                     0.202064
# grade                                         0.122783
# lat                                          -0.849121
# long                                          0.387819
# yr_built_scaled                               0.166599
# yr_renovated_scaled                           0.157838
# age_yr_sold                                  -0.166439
# mean_grade_per_zipcode                        0.566089
# mode_grade_per_zipcode                       -0.142766
# mean_condition_per_zipcode                    1.000000
# mode_condition_per_zipcode                    0.960508
#
#                             mode_condition_per_zipcode
# price_log                                     0.008477
# sqft_living_log                               0.175934
# sqft_lot_log                                  0.357352
# sqft_living15_log                             0.271378
# sqft_lot15_log                                0.359238
# waterfront                                    0.144805
# view                                          0.256005
# condition                                     0.194084
# grade                                         0.116479
# lat                                          -0.862526
# long                                          0.313714
# yr_built_scaled                               0.175449
# yr_renovated_scaled                           0.158800
# age_yr_sold                                  -0.175370
# mean_grade_per_zipcode                        0.537027
# mode_grade_per_zipcode                       -0.140010
# mean_condition_per_zipcode                    0.960508
# mode_condition_per_zipcode                    1.000000

# %%
formula = "price_log~mode_grade_per_zipcode+sqft_living_log+sqft_lot_log"
model = ols(formula = formula, data = df_working1).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              price_log   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     943.9
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):          1.98e-293
# Time:                        15:19:06   Log-Likelihood:                -45.725
# No. Observations:                1022   AIC:                             99.45
# Df Residuals:                    1018   BIC:                             119.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  4.4631      0.311     14.338      0.000       3.852       5.074
# mode_grade_per_zipcode     0.2940      0.038      7.826      0.000       0.220       0.368
# sqft_living_log            0.8228      0.021     39.401      0.000       0.782       0.864
# sqft_lot_log               0.0682      0.012      5.635      0.000       0.044       0.092
# ==============================================================================
# Omnibus:                        2.561   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                2.598
# Skew:                          -0.053   Prob(JB):                        0.273
# Kurtosis:                       3.223   Cond. No.                         570.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_working1[["mode_grade_per_zipcode","sqft_living_log","sqft_lot_log"]].corr()
# Out:
#                         mode_grade_per_zipcode  sqft_living_log  sqft_lot_log
# mode_grade_per_zipcode                1.000000         0.149225      0.200859
# sqft_living_log                       0.149225         1.000000      0.550350
# sqft_lot_log                          0.200859         0.550350      1.000000

# %%
import scipy.stats as stats
residuals = model.resid
fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Model in the not Waterfront Properties

# %%
df_working2 = df_working.loc[(df_working["zipcode"] != 98039) 
                         & (df_working["zipcode"] != 98004)
                         & (df_working["zipcode"] != 98040)
                         & (df_working["zipcode"] != 98112)
                         & (df_working["zipcode"] != 98102)]

(df_working2["zipcode"].unique())
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98092, 98030, 98119, 98052, 98027, 98117, 98058, 98001, 98056,
#        98166, 98023, 98070, 98148, 98105, 98042, 98008, 98059, 98122,
#        98144, 98005, 98034, 98075, 98116, 98010, 98118, 98199, 98032,
#        98045, 98077, 98108, 98168, 98177, 98065, 98029, 98006, 98109,
#        98022, 98033, 98155, 98024, 98011, 98031, 98106, 98072, 98188,
#        98014, 98055])

# %%
df_working2[['price_log','sqft_living_log', 'sqft_lot_log', 'sqft_living15_log',
       'sqft_lot15_log','waterfront', 'view', 'condition', 'grade', 'lat',
       'long', 'yr_built_scaled', 'yr_renovated_scaled', 'age_yr_sold', 'mean_grade_per_zipcode',
       'mode_grade_per_zipcode', 'mean_condition_per_zipcode',
       'mode_condition_per_zipcode']].corr()
# Out:
#                             price_log  sqft_living_log  sqft_lot_log  \
# price_log                    1.000000         0.662485      0.129154
# sqft_living_log              0.662485         1.000000      0.318991
# sqft_lot_log                 0.129154         0.318991      1.000000
# sqft_living15_log            0.585886         0.744625      0.356594
# sqft_lot15_log               0.109412         0.294708      0.917979
# waterfront                   0.173137         0.072855      0.071047
# view                         0.350436         0.234852      0.110642
# condition                    0.019452        -0.064099      0.068956
# grade                        0.687600         0.732869      0.178772
# lat                          0.465420         0.030267     -0.148815
# long                         0.072947         0.272786      0.374457
# yr_built_scaled              0.105377         0.372323     -0.011202
# yr_renovated_scaled          0.141041         0.388726     -0.017756
# age_yr_sold                 -0.105277        -0.372791      0.011028
# mean_grade_per_zipcode       0.500772         0.384722      0.183633
# mode_grade_per_zipcode       0.346379         0.277821      0.145630
# mean_condition_per_zipcode   0.030991        -0.095189     -0.092614
# mode_condition_per_zipcode   0.001523         0.008352      0.089134
#
#                             sqft_living15_log  sqft_lot15_log  waterfront  \
# price_log                            0.585886        0.109412    0.173137
# sqft_living_log                      0.744625        0.294708    0.072855
# sqft_lot_log                         0.356594        0.917979    0.071047
# sqft_living15_log                    1.000000        0.364210    0.069740
# sqft_lot15_log                       0.364210        1.000000    0.079134
# waterfront                           0.069740        0.079134    1.000000
# view                                 0.250288        0.107270    0.381954
# condition                           -0.115471        0.074461    0.013621
# grade                                0.686281        0.177739    0.078679
# lat                                  0.034351       -0.143890   -0.012310
# long                                 0.357878        0.375414   -0.039852
# yr_built_scaled                      0.366817        0.013491   -0.026146
# yr_renovated_scaled                  0.359532        0.007140   -0.008497
# age_yr_sold                         -0.367136       -0.013660    0.026058
# mean_grade_per_zipcode               0.499037        0.190602   -0.007447
# mode_grade_per_zipcode               0.364410        0.153578    0.007689
# mean_condition_per_zipcode          -0.140366       -0.087325    0.034397
# mode_condition_per_zipcode           0.000424        0.098252    0.061992
#
#                                 view  condition     grade       lat      long  \
# price_log                   0.350436   0.019452  0.687600  0.465420  0.072947
# sqft_living_log             0.234852  -0.064099  0.732869  0.030267  0.272786
# sqft_lot_log                0.110642   0.068956  0.178772 -0.148815  0.374457
# sqft_living15_log           0.250288  -0.115471  0.686281  0.034351  0.357878
# sqft_lot15_log              0.107270   0.074461  0.177739 -0.143890  0.375414
# waterfront                  0.381954   0.013621  0.078679 -0.012310 -0.039852
# view                        1.000000   0.044046  0.241080  0.006646 -0.081831
# condition                   0.044046   1.000000 -0.167906 -0.017427 -0.107560
# grade                       0.241080  -0.167906  1.000000  0.106094  0.220810
# lat                         0.006646  -0.017427  0.106094  1.000000 -0.130788
# long                       -0.081831  -0.107560  0.220810 -0.130788  1.000000
# yr_built_scaled            -0.060550  -0.363135  0.473755 -0.145964  0.414561
# yr_renovated_scaled        -0.033845  -0.390778  0.482233 -0.136596  0.391442
# age_yr_sold                 0.060575   0.362373 -0.474210  0.145499 -0.414565
# mean_grade_per_zipcode      0.018794  -0.045553  0.463651  0.226214  0.476465
# mode_grade_per_zipcode      0.012788  -0.073097  0.359971  0.155382  0.346842
# mean_condition_per_zipcode  0.091485   0.251533 -0.083968 -0.055012 -0.424482
# mode_condition_per_zipcode  0.018350   0.098961 -0.012655 -0.089487  0.010625
#
#                             yr_built_scaled  yr_renovated_scaled  age_yr_sold  \
# price_log                          0.105377             0.141041    -0.105277
# sqft_living_log                    0.372323             0.388726    -0.372791
# sqft_lot_log                      -0.011202            -0.017756     0.011028
# sqft_living15_log                  0.366817             0.359532    -0.367136
# sqft_lot15_log                     0.013491             0.007140    -0.013660
# waterfront                        -0.026146            -0.008497     0.026058
# view                              -0.060550            -0.033845     0.060575
# condition                         -0.363135            -0.390778     0.362373
# grade                              0.473755             0.482233    -0.474210
# lat                               -0.145964            -0.136596     0.145499
# long                               0.414561             0.391442    -0.414565
# yr_built_scaled                    1.000000             0.929888    -0.999871
# yr_renovated_scaled                0.929888             1.000000    -0.929858
# age_yr_sold                       -0.999871            -0.929858     1.000000
# mean_grade_per_zipcode             0.289080             0.281875    -0.289440
# mode_grade_per_zipcode             0.198321             0.193773    -0.198691
# mean_condition_per_zipcode        -0.251391            -0.239031     0.251371
# mode_condition_per_zipcode        -0.028039            -0.033497     0.027868
#
#                             mean_grade_per_zipcode  mode_grade_per_zipcode  \
# price_log                                 0.500772                0.346379
# sqft_living_log                           0.384722                0.277821
# sqft_lot_log                              0.183633                0.145630
# sqft_living15_log                         0.499037                0.364410
# sqft_lot15_log                            0.190602                0.153578
# waterfront                               -0.007447                0.007689
# view                                      0.018794                0.012788
# condition                                -0.045553               -0.073097
# grade                                     0.463651                0.359971
# lat                                       0.226214                0.155382
# long                                      0.476465                0.346842
# yr_built_scaled                           0.289080                0.198321
# yr_renovated_scaled                       0.281875                0.193773
# age_yr_sold                              -0.289440               -0.198691
# mean_grade_per_zipcode                    1.000000                0.776385
# mode_grade_per_zipcode                    0.776385                1.000000
# mean_condition_per_zipcode               -0.181101               -0.290607
# mode_condition_per_zipcode               -0.027295               -0.047183
#
#                             mean_condition_per_zipcode  \
# price_log                                     0.030991
# sqft_living_log                              -0.095189
# sqft_lot_log                                 -0.092614
# sqft_living15_log                            -0.140366
# sqft_lot15_log                               -0.087325
# waterfront                                    0.034397
# view                                          0.091485
# condition                                     0.251533
# grade                                        -0.083968
# lat                                          -0.055012
# long                                         -0.424482
# yr_built_scaled                              -0.251391
# yr_renovated_scaled                          -0.239031
# age_yr_sold                                   0.251371
# mean_grade_per_zipcode                       -0.181101
# mode_grade_per_zipcode                       -0.290607
# mean_condition_per_zipcode                    1.000000
# mode_condition_per_zipcode                    0.393431
#
#                             mode_condition_per_zipcode
# price_log                                     0.001523
# sqft_living_log                               0.008352
# sqft_lot_log                                  0.089134
# sqft_living15_log                             0.000424
# sqft_lot15_log                                0.098252
# waterfront                                    0.061992
# view                                          0.018350
# condition                                     0.098961
# grade                                        -0.012655
# lat                                          -0.089487
# long                                          0.010625
# yr_built_scaled                              -0.028039
# yr_renovated_scaled                          -0.033497
# age_yr_sold                                   0.027868
# mean_grade_per_zipcode                       -0.027295
# mode_grade_per_zipcode                       -0.047183
# mean_condition_per_zipcode                    0.393431
# mode_condition_per_zipcode                    1.000000

# %%
formula = "price_log~sqft_living_log+sqft_lot_log+mean_grade_per_zipcode+waterfront+age_yr_sold+view"
model = ols(formula = formula, data = df_working2).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              price_log   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     5420.
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):               0.00
# Time:                        15:15:38   Log-Likelihood:                -4811.9
# No. Observations:               20570   AIC:                             9638.
# Df Residuals:                   20563   BIC:                             9693.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  5.6720      0.049    115.307      0.000       5.576       5.768
# sqft_living_log            0.7174      0.006    113.486      0.000       0.705       0.730
# sqft_lot_log              -0.0853      0.003    -33.740      0.000      -0.090      -0.080
# mean_grade_per_zipcode     0.3302      0.004     73.773      0.000       0.321       0.339
# waterfront                 0.4207      0.029     14.599      0.000       0.364       0.477
# age_yr_sold                0.0036   8.19e-05     43.846      0.000       0.003       0.004
# view                       0.1166      0.003     36.668      0.000       0.110       0.123
# ==============================================================================
# Omnibus:                       32.529   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.164
# Skew:                           0.012   Prob(JB):                     3.13e-09
# Kurtosis:                       3.212   Cond. No.                     1.23e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_working2[["sqft_living_log","sqft_lot_log","grade", "condition", "mean_grade_per_zipcode", "age_yr_sold", "waterfront", "view"]].corr()
# Out:
#                         sqft_living_log  sqft_lot_log     grade  condition  \
# sqft_living_log                1.000000      0.318991  0.732869  -0.064099
# sqft_lot_log                   0.318991      1.000000  0.178772   0.068956
# grade                          0.732869      0.178772  1.000000  -0.167906
# condition                     -0.064099      0.068956 -0.167906   1.000000
# mean_grade_per_zipcode         0.384722      0.183633  0.463651  -0.045553
# age_yr_sold                   -0.372791      0.011028 -0.474210   0.362373
# waterfront                     0.072855      0.071047  0.078679   0.013621
# view                           0.234852      0.110642  0.241080   0.044046
#
#                         mean_grade_per_zipcode  age_yr_sold  waterfront  \
# sqft_living_log                       0.384722    -0.372791    0.072855
# sqft_lot_log                          0.183633     0.011028    0.071047
# grade                                 0.463651    -0.474210    0.078679
# condition                            -0.045553     0.362373    0.013621
# mean_grade_per_zipcode                1.000000    -0.289440   -0.007447
# age_yr_sold                          -0.289440     1.000000    0.026058
# waterfront                           -0.007447     0.026058    1.000000
# view                                  0.018794     0.060575    0.381954
#
#                             view
# sqft_living_log         0.234852
# sqft_lot_log            0.110642
# grade                   0.241080
# condition               0.044046
# mean_grade_per_zipcode  0.018794
# age_yr_sold             0.060575
# waterfront              0.381954
# view                    1.000000

# %%
import scipy.stats as stats
residuals = model.resid
fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %% [markdown]
# So, as it stands, one subset model is better than our universal model, and the other is worse.
# However, I think with a better understanding of what is going on here, we would be able to improve these models to overtake the universal model. Perhaps once we addressed the categorical data with the dummies trick, and scaled properly, we could run them all through a recurrsive function to return the best predictors to use!

# %% [markdown]
# # Answering our interesting questions

# %% [markdown]
# ## How much volatility was there in the housing market in Seattle in 2014/2015?

# %% [markdown]
# We observed arbitrarily that some of the houses that had been sold in this period twice, and had been sold for huge profits. We wanted to investigate this further...

# %%
df_resold = pd.DataFrame(data = df_final[df_final.duplicated(subset='id', keep = False)], columns = ['zipcode','id', 'date_formatted','yr_built', 'yr_renovated','age_yr_sold','grade', 'condition','price']).sort_values(by = ['zipcode', 'id'])
df_resold.reset_index(inplace = True)
df_resold.head()
# Out:
#    index  zipcode          id date_formatted  yr_built  yr_renovated  \
# 0   9225    98001   302000375     2014-08-14      1953          1953
# 1   9226    98001   302000375     2015-05-06      1953          1953
# 2  12196    98001  4031000520     2014-07-08      1962          1962
# 3  12197    98001  4031000520     2014-11-25      1962          1962
# 4  17119    98001  6143000020     2014-10-27      1963          1963
#
#    age_yr_sold  grade  condition     price
# 0           61      7          4  169100.0
# 1           62      7          4  250000.0
# 2           52      7          4  115000.0
# 3           52      7          4  227000.0
# 4           51      8          4  175000.0

# %%
df_resold['price_percent_change'] = pd.Series()

for i in range(len(df_resold)):
    if i == 0:
        df_resold.iloc[i,10]= np.nan
    else:
        if df_resold.iloc[i,2] == df_resold.iloc[i-1,2]:
            df_resold.iloc[i,10] = (df_resold.iloc[i,9] - df_resold.iloc[i-1,9])/df_resold.iloc[i,9]
        else:
            df_resold.iloc[i,10] = np.nan

df_resold.head()
# Out:
#    index  zipcode          id date_formatted  yr_built  yr_renovated  \
# 0   9225    98001   302000375     2014-08-14      1953          1953
# 1   9226    98001   302000375     2015-05-06      1953          1953
# 2  12196    98001  4031000520     2014-07-08      1962          1962
# 3  12197    98001  4031000520     2014-11-25      1962          1962
# 4  17119    98001  6143000020     2014-10-27      1963          1963
#
#    age_yr_sold  grade  condition     price  price_percent_change
# 0           61      7          4  169100.0                   NaN
# 1           62      7          4  250000.0              0.323600
# 2           52      7          4  115000.0                   NaN
# 3           52      7          4  227000.0              0.493392
# 4           51      8          4  175000.0                   NaN

# %%
#mean percentage change per zipcode

df_resold.groupby(df_resold['zipcode'])['price_percent_change'].mean().sort_values(ascending = False).head(20)
# Out:
# zipcode
# 98148    0.762921
# 98116    0.561002
# 98032    0.517309
# 98126    0.496990
# 98118    0.460201
# 98178    0.449338
# 98011    0.446809
# 98117    0.436667
# 98034    0.436024
# 98106    0.424898
# 98155    0.418203
# 98001    0.410569
# 98198    0.404218
# 98030    0.396758
# 98042    0.396113
# 98122    0.395349
# 98133    0.386473
# 98146    0.383439
# 98003    0.382319
# 98166    0.378854
# Name: price_percent_change, dtype: float64

# %%
#calculate days between date sold per id

import datetime

df_resold['mean_days'] = pd.Series()

for i in range(len(df_resold)):
    if i == 0:
        df_resold.iloc[i,11]= np.nan
    else:
        if df_resold.iloc[i,2] == df_resold.iloc[i-1,2]:
            date1 = df_resold.iloc[i,3]
            date2 = df_resold.iloc[i-1,3]
            df_resold.iloc[i,11] = (date1 - date2).days
        else:
            df_resold.iloc[i,11] = np.nan
            
df_resold.head(20)
# Out:
#     index  zipcode          id date_formatted  yr_built  yr_renovated  \
# 0    9225    98001   302000375     2014-08-14      1953          1953
# 1    9226    98001   302000375     2015-05-06      1953          1953
# 2   12196    98001  4031000520     2014-07-08      1962          1962
# 3   12197    98001  4031000520     2014-11-25      1962          1962
# 4   17119    98001  6143000020     2014-10-27      1963          1963
# 5   17120    98001  6143000020     2015-04-06      1963          1963
# 6    2494    98002     1000102     2014-09-16      1991          1991
# 7    2495    98002     1000102     2015-04-22      1991          1991
# 8   10261    98002  1450100390     2014-09-05      1960          1960
# 9   10262    98002  1450100390     2015-03-16      1960          1960
# 10   7785    98003   251300110     2014-07-31      1988          1988
# 11   7786    98003   251300110     2015-01-14      1988          1988
# 12  12942    98003  2019200220     2014-09-23      1985          1985
# 13  12943    98003  2019200220     2015-02-26      1985          1985
# 14  14979    98003  4222310010     2014-12-26      1970          1970
# 15  14980    98003  4222310010     2015-04-20      1970          1970
# 16   2629    98003  7983000200     2014-10-05      1968          1968
# 17   2630    98003  7983000200     2015-02-25      1968          1968
# 18  15998    98004  5536100020     2014-12-15      1951          1951
# 19  15999    98004  5536100020     2015-05-12      1951          1951
#
#     age_yr_sold  grade  condition      price  price_percent_change  mean_days
# 0            61      7          4   169100.0                   NaN        NaN
# 1            62      7          4   250000.0              0.323600      265.0
# 2            52      7          4   115000.0                   NaN        NaN
# 3            52      7          4   227000.0              0.493392      140.0
# 4            51      8          4   175000.0                   NaN        NaN
# 5            52      8          4   299000.0              0.414716      161.0
# 6            23      7          3   280000.0                   NaN        NaN
# 7            24      7          3   300000.0              0.066667      218.0
# 8            54      6          3   125000.0                   NaN        NaN
# 9            55      6          3   208000.0              0.399038      192.0
# 10           26      8          3   225000.0                   NaN        NaN
# 11           27      8          3   358000.0              0.371508      167.0
# 12           29      7          3   160000.0                   NaN        NaN
# 13           30      7          3   269000.0              0.405204      156.0
# 14           44      6          4   152500.0                   NaN        NaN
# 15           45      6          4   267950.0              0.430864      115.0
# 16           46      7          3   169575.0                   NaN        NaN
# 17           47      7          3   250000.0              0.321700      143.0
# 18           63      8          3   987000.0                   NaN        NaN
# 19           64      8          3  1190000.0              0.170588      148.0

# %%
df_resold['change_grade'] = pd.Series()
df_resold['change_condition'] = pd.Series()

for i in range(len(df_resold)):
    if i == 0:
        df_resold.iloc[i,12]= np.nan
        df_resold.iloc[i,13]= np.nan
    else:
        if df_resold.iloc[i,2] == df_resold.iloc[i-1,2]:
            df_resold.iloc[i,12] = (df_resold.iloc[i,7] - df_resold.iloc[i-1,7])
            df_resold.iloc[i,13] = (df_resold.iloc[i,8] - df_resold.iloc[i-1,8])
        else:
            df_resold.iloc[i,12]= np.nan
            df_resold.iloc[i,13]= np.nan

df_resold.head()
# Out:
#    index  zipcode          id date_formatted  yr_built  yr_renovated  \
# 0   9225    98001   302000375     2014-08-14      1953          1953
# 1   9226    98001   302000375     2015-05-06      1953          1953
# 2  12196    98001  4031000520     2014-07-08      1962          1962
# 3  12197    98001  4031000520     2014-11-25      1962          1962
# 4  17119    98001  6143000020     2014-10-27      1963          1963
#
#    age_yr_sold  grade  condition     price  price_percent_change  mean_days  \
# 0           61      7          4  169100.0                   NaN        NaN
# 1           62      7          4  250000.0              0.323600      265.0
# 2           52      7          4  115000.0                   NaN        NaN
# 3           52      7          4  227000.0              0.493392      140.0
# 4           51      8          4  175000.0                   NaN        NaN
#
#    change_grade  change_condition
# 0           NaN               NaN
# 1           0.0               0.0
# 2           NaN               NaN
# 3           0.0               0.0
# 4           NaN               NaN

# %%
#positive value means the property was renovated 

df_resold['renovated'] = pd.Series()

for i in range(len(df_resold)):
    if i == 0:
        df_resold.iloc[i,14]= np.nan
    else:
        if df_resold.iloc[i,5] == df_resold.iloc[i-1,5]:
            df_resold.iloc[i,14] = df_resold.iloc[i,5] - df_resold.iloc[i-1,5]
        else:
            df_resold.iloc[i,14]= np.nan

df_resold[["zipcode", 'id', 'price','yr_renovated',  'price_percent_change', 'mean_days', 'change_grade', 'change_condition', 'renovated']]
# Out:
#      zipcode          id     price  yr_renovated  price_percent_change  \
# 0      98001   302000375  169100.0          1953                   NaN
# 1      98001   302000375  250000.0          1953              0.323600
# 2      98001  4031000520  115000.0          1962                   NaN
# 3      98001  4031000520  227000.0          1962              0.493392
# 4      98001  6143000020  175000.0          1963                   NaN
# ..       ...         ...       ...           ...                   ...
# 348    98198  7888000390  235000.0          1959              0.404255
# 349    98198  7893805650  210000.0          1956                   NaN
# 350    98198  7893805650  475000.0          1956              0.557895
# 351    98199  3271300955  554729.0          1943                   NaN
# 352    98199  3271300955  868000.0          1943              0.360911
#
#      mean_days  change_grade  change_condition  renovated
# 0          NaN           NaN               NaN        NaN
# 1        265.0           0.0               0.0        0.0
# 2          NaN           NaN               NaN        NaN
# 3        140.0           0.0               0.0        0.0
# 4          NaN           NaN               NaN        NaN
# ..         ...           ...               ...        ...
# 348      278.0           0.0               0.0        0.0
# 349        NaN           NaN               NaN        NaN
# 350      312.0           0.0               0.0        0.0
# 351        NaN           NaN               NaN        NaN
# 352      236.0           0.0               0.0        0.0
#
# [353 rows x 9 columns]

# %%
#mean percentage change and days per zipcode, and note that there is no change in general condition or grade

df_resold.groupby(df_resold['zipcode'])['price_percent_change','mean_days', 'change_grade','change_condition','renovated'].mean().sort_values(by="price_percent_change", ascending = False).head()
# Out:
#          price_percent_change   mean_days  change_grade  change_condition  \
# zipcode
# 98148                0.762921  243.000000           0.0               0.0
# 98116                0.561002  258.000000           0.0               0.0
# 98032                0.517309  119.000000           0.0               0.0
# 98126                0.496990  146.500000           0.0               0.0
# 98118                0.460201  184.555556           0.0               0.0
#
#          renovated
# zipcode
# 98148          0.0
# 98116          0.0
# 98032          0.0
# 98126          0.0
# 98118          0.0

# %% [markdown]
# There is some actual madness going on with this data. We could investiaget further into the renovations of these houses, but even that wouldn't be enough explanation as to why we have so many people making hundreds of thousands of dollars profit on buying and selling their homes less than a year later. Money laundering going on?

# %% [markdown]
# ## What year's houses have lasted the best?

# %% [markdown]
# We will plot condition against age, and expect to see a decent corrolation showing that the older houses are in poorer condition. We shouldn't include houses that that been renovated. We could even run a univariate analysis to find which year/time period buck the trend more that you'd expect.

# %%
df_test = pd.read_csv("kc_house_data.csv")
df_condition_test = df_test.drop(columns=['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'grade',
       'sqft_above', 'sqft_basement', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15','yr_renovated'])
df_condition_test.head(20)
# Out:
#     condition  yr_built
# 0           3      1955
# 1           3      1951
# 2           3      1933
# 3           5      1965
# 4           3      1987
# 5           3      2001
# 6           3      1995
# 7           3      1963
# 8           3      1960
# 9           3      2003
# 10          3      1965
# 11          4      1942
# 12          4      1927
# 13          4      1977
# 14          3      1900
# 15          3      1979
# 16          3      1994
# 17          4      1916
# 18          4      1921
# 19          4      1969

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(16, 8))

x = sns.lineplot(x="yr_built", y="condition", data=df_condition_test,err_style=None)
x.set(xlim=(1900,2015), ylim=(2.9,4))
plt.title("Condition change over time")
# Out:
# Text(0.5, 1.0, 'Condition change over time')

# %% [markdown]
# As we can see above, these houses have not been renovated, and the condition of them today varies. It is interesting to note that the houses that are currently in the best condition were those built in 1917, and those that were the worst was in 1931. The houses built in 1931 were those closest to the stock market crash of 1929 (very few houses built in 1930), and as there was much less money, the houses were not built to last. Isn't it interesting how the condition of houses has been on a steady decline since 1975?

# %% [markdown]
# ## What further data would be useful for improving our model?

# %% [markdown]
# The following factors we believe would be interesting additions to our model, because they would be easy to calculate/investigate, and real estate agents in real life take them into consideration when pricing homes:
# - Zoning Value
#     - The average price per square foot of your 15 closest neighbours of lot and living seperately. Prices per square foot change from one Zip Code to another, and we think therefore that we might improve our model by subsetting over zipcodes that have similar values for these average square foots.
# - Lot Type
#     - A catagorical variable, giving us a further description of the location of the house. For example, it's important to know if a house is in a cul-de-sac, on a main road, on a corner lot, on the perimeter of a neighbourhood, T-Lot (some customers think its bad luck) or if a house is 'haunted'.
# - Restrictions or Encumberances
#     - A categorical variable that will tell whether the property has a clean title.  Buyer and real estate agents should be aware of the limitations and threats to property ownership. These will reduce the price and make it less marketable.
# - More information on Location
#     - Close to flood zones, proximity to schools/cemetary/shopping malls. Air pollution in different zipcodes. Crime rate in the location.
